# %% [markdown]
# # CityBikes

# %% [markdown]
# Send a request to CityBikes for the city of your choice.

# %%
import requests
import pandas as pd
import pprint 

response = requests.get("http://api.citybik.es/v2/networks/bixi-toronto")

data = response.json()

# %% [markdown]
# Parse through the response to get the details you want for the bike stations in that city (latitude, longitude, number of bikes).

# %%
pprint.pp(data)
# Out:
# {'network': {'id': 'bixi-toronto',
#              'name': 'Bike Share Toronto',
#              'location': {'latitude': 43.653226,
#                           'longitude': -79.3831843,
#                           'city': 'Toronto, ON',
#                           'country': 'CA'},
#              'href': '/v2/networks/bixi-toronto',
#              'company': ['Motivate International, Inc.',
#                          'PBSC Urban Solutions'],
#              'gbfs_href': 'https://tor.publicbikesystem.net/ube/gbfs/v1/',
#              'stations': [{'id': '009f180cf35ae1285733d98ccf058313',
#                            'name': 'Summerhill Ave / Maclennan Ave',
#                            'latitude': 43.685924,
#                            'longitude': -79.376304,
#                            'timestamp': '2025-02-01T01:41:37.949238Z',
#                            'free_bikes': 0,
#                            'empty_slots': 8,
#                            'extra': {'uid': '7488',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373920,
#                                      'address': 'Summerhill Ave / Maclennan '
#                                                 'Ave',
#                                      'post_code': 'M4M 2Z9',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 0,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': None,
#                                      'slots': 11,
#                                      'rental_uris': {}}},
#                           {'id': '010507feed5b8d87c40cd95933ed5654',
#                            'name': 'Queen St E / Joseph Duggan Rd',
#                            'latitude': 43.6677628,
#                            'longitude': -79.30811709999999,
#                            'timestamp': '2025-02-01T01:41:37.958366Z',
#                            'free_bikes': 11,
#                            'empty_slots': 7,
#                            'extra': {'uid': '7695',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738374000,
#                                      'address': 'Queen St E and Joseph Duggan '
#                                                 'Rd',
#                                      'post_code': 'M4L 3Y2',
#                                      'has_ebikes': True,
#                                      'ebikes': 2,
#                                      'normal_bikes': 9,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'altitude': 0.0,
#                                      'slots': 19,
#                                      'rental_uris': {}}},
#                           {'id': '0153756b9e136b96e730aaa2f048227f',
#                            'name': 'Victoria Park Ave / Danforth Ave',
#                            'latitude': 43.691468,
#                            'longitude': -79.288619,
#                            'timestamp': '2025-02-01T01:41:37.950454Z',
#                            'free_bikes': 2,
#                            'empty_slots': 17,
#                            'extra': {'uid': '7611',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373938,
#                                      'address': 'Victoria Park Ave / Danforth '
#                                                 'Ave',
#                                      'post_code': 'M4C 1N2',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 2,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': 0.0,
#                                      'slots': 19,
#                                      'rental_uris': {}}},
#                           {'id': '019e5937c3fc120cee906770bca8fa69',
#                            'name': 'Navy Wharf Crt / Bremner Blvd',
#                            'latitude': 43.640722,
#                            'longitude': -79.391051,
#                            'timestamp': '2025-02-01T01:41:37.944663Z',
#                            'free_bikes': 8,
#                            'empty_slots': 0,
#                            'extra': {'uid': '7054',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738374080,
#                                      'address': 'Navy Wharf Ct. / Bremner '
#                                                 'Blvd.',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 8,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': None,
#                                      'slots': 9,
#                                      'rental_uris': {}}},
#                           {'id': '01caf8b12874b091f2fccc3818e3c72e',
#                            'name': '420 Wellington St W',
#                            'latitude': 43.643834,
#                            'longitude': -79.396649,
#                            'timestamp': '2025-02-01T01:41:37.945317Z',
#                            'free_bikes': 10,
#                            'empty_slots': 2,
#                            'extra': {'uid': '7123',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373992,
#                                      'address': '420 Wellington St W',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 10,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': None,
#                                      'slots': 14,
#                                      'rental_uris': {}}},
#                           {'id': '022818120bd4e5138186fe1ab57f791a',
#                            'name': 'Sentinel Rd / Finch Ave W',
#                            'latitude': 43.76073963892478,
#                            'longitude': -79.5000273116394,
#                            'timestamp': '2025-02-01T01:41:37.960764Z',
#                            'free_bikes': 5,
#                            'empty_slots': 8,
#                            'extra': {'uid': '7873',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373944,
#                                      'address': '390 Sentinel Rd',
#                                      'post_code': 'M3J 1V3',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 5,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'altitude': 0.0,
#                                      'slots': 14,
#                                      'rental_uris': {}}},
#                           {'id': '026bf7c2104a659ef0392f1c22bc6e17',
#                            'name': 'Ross St / Cecil St - SMART',
#                            'latitude': 43.6568254,
#                            'longitude': -79.3966159,
#                            'timestamp': '2025-02-01T01:41:37.949730Z',
#                            'free_bikes': 12,
#                            'empty_slots': 6,
#                            'extra': {'uid': '7546',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738374086,
#                                      'address': 'Ross St / Cecil St',
#                                      'post_code': 'M5T 1N3',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 12,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'altitude': 0.0,
#                                      'slots': 18,
#                                      'rental_uris': {}}},
#                           {'id': '02d90c8ede19da66083e0d0e14d17258',
#                            'name': 'York University Station (North)',
#                            'latitude': 43.7741,
#                            'longitude': -79.5005,
#                            'timestamp': '2025-02-01T01:41:37.958231Z',
#                            'free_bikes': 0,
#                            'empty_slots': 15,
#                            'extra': {'uid': '7679',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738374063,
#                                      'address': 'York University Station',
#                                      'post_code': 'M3J',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 0,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': 0.0,
#                                      'slots': 15,
#                                      'rental_uris': {}}},
#                           {'id': '02feaaef65cff4671fb1935179895659',
#                            'name': 'Dundas St W / Yonge St',
#                            'latitude': 43.656094,
#                            'longitude': -79.381484,
#                            'timestamp': '2025-02-01T01:41:37.944496Z',
#                            'free_bikes': 11,
#                            'empty_slots': 4,
#                            'extra': {'uid': '7038',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373953,
#                                      'address': 'Dundas St W / Yonge St',
#                                      'has_ebikes': True,
#                                      'ebikes': 1,
#                                      'normal_bikes': 10,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': None,
#                                      'slots': 15,
#                                      'rental_uris': {}}},
#                           {'id': '033dd75f330fec10400341177c68036e',
#                            'name': 'Seaton St / Dundas St E - SMART',
#                            'latitude': 43.658777,
#                            'longitude': -79.369596,
#                            'timestamp': '2025-02-01T01:41:37.945164Z',
#                            'free_bikes': 1,
#                            'empty_slots': 30,
#                            'extra': {'uid': '7109',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373927,
#                                      'address': 'Seaton St / Dundas St E',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 1,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'altitude': None,
#                                      'slots': 32,
#                                      'rental_uris': {}}},
#                           {'id': '03b565f085260e768988cd216fbeeef4',
#                            'name': 'Euclid Ave / Herrick St - SMART',
#                            'latitude': 43.661559,
#                            'longitude': -79.413845,
#                            'timestamp': '2025-02-01T01:41:37.949637Z',
#                            'free_bikes': 0,
#                            'empty_slots': 16,
#                            'extra': {'uid': '7537',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373983,
#                                      'address': 'Euclid Ave / Herrick St',
#                                      'post_code': 'M6G 2T4',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 0,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'altitude': 0.0,
#                                      'slots': 16,
#                                      'rental_uris': {}}},
#                           {'id': '03cb067499bb9bc86cf0c884edb403bc',
#                            'name': "Wellesley St W / Queen's Park Cres",
#                            'latitude': 43.663376,
#                            'longitude': -79.392125,
#                            'timestamp': '2025-02-01T01:41:37.944172Z',
#                            'free_bikes': 3,
#                            'empty_slots': 14,
#                            'extra': {'uid': '7008',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738374085,
#                                      'address': "Wellesley St W / Queen's Park "
#                                                 'Cres',
#                                      'has_ebikes': True,
#                                      'ebikes': 1,
#                                      'normal_bikes': 2,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': None,
#                                      'slots': 18,
#                                      'rental_uris': {}}},
#                           {'id': '045a7a6b973238dc76bc058e4f33f143',
#                            'name': 'Wellington St W / Bay St',
#                            'latitude': 43.647259,
#                            'longitude': -79.379878,
#                            'timestamp': '2025-02-01T01:41:37.944641Z',
#                            'free_bikes': 6,
#                            'empty_slots': 49,
#                            'extra': {'uid': '7052',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738374024,
#                                      'address': 'Wellington St W / Bay St',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 6,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'altitude': None,
#                                      'slots': 55,
#                                      'rental_uris': {}}},
#                           {'id': '049156f7c0e19a53a77d8310d93eed0c',
#                            'name': 'Sunnyside Ave / The Queensway - SMART',
#                            'latitude': 43.6397,
#                            'longitude': -79.44865,
#                            'timestamp': '2025-02-01T01:41:37.949292Z',
#                            'free_bikes': 10,
#                            'empty_slots': 9,
#                            'extra': {'uid': '7496',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373924,
#                                      'address': 'Sunnyside Ave / The Queensway '
#                                                 '- SMART',
#                                      'post_code': 'M6R 1B4',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 10,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'altitude': None,
#                                      'slots': 19,
#                                      'rental_uris': {}}},
#                           {'id': '049c76540151608ec55bfcd0e1748f41',
#                            'name': '161 Bleecker St (South of Wellesley)',
#                            'latitude': 43.666233,
#                            'longitude': -79.373327,
#                            'timestamp': '2025-02-01T01:41:37.944797Z',
#                            'free_bikes': 2,
#                            'empty_slots': 21,
#                            'extra': {'uid': '7071',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373921,
#                                      'address': '161 Bleecker St (South of '
#                                                 'Wellesley)',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 2,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': 0.0,
#                                      'slots': 23,
#                                      'rental_uris': {}}},
#                           {'id': '04cadbe0f9b27f89f5fa6f6dbdea0883',
#                            'name': 'Bay St / Scollard St',
#                            'latitude': 43.672152,
#                            'longitude': -79.39018,
#                            'timestamp': '2025-02-01T01:41:37.945350Z',
#                            'free_bikes': 1,
#                            'empty_slots': 12,
#                            'extra': {'uid': '7127',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738374087,
#                                      'address': 'Bay St / Scollard St',
#                                      'post_code': 'M5R 0A1',
#                                      'has_ebikes': True,
#                                      'ebikes': 1,
#                                      'normal_bikes': 0,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': None,
#                                      'slots': 15,
#                                      'rental_uris': {}}},
#                           {'id': '052763ac927bce9197aa6381f508576f',
#                            'name': 'Pape Ave / Gamble Ave',
#                            'latitude': 43.690237,
#                            'longitude': -79.350119,
#                            'timestamp': '2025-02-01T01:41:37.947788Z',
#                            'free_bikes': 5,
#                            'empty_slots': 14,
#                            'extra': {'uid': '7348',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373962,
#                                      'address': 'Pape Ave / Gamble Ave',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 5,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': None,
#                                      'slots': 19,
#                                      'rental_uris': {}}},
#                           {'id': '05d7abba295be4af9e74ca3ec241ebd7',
#                            'name': 'Queen St E / Hammersmith Ave',
#                            'latitude': 43.671349,
#                            'longitude': -79.29451,
#                            'timestamp': '2025-02-01T01:41:37.947318Z',
#                            'free_bikes': 9,
#                            'empty_slots': 2,
#                            'extra': {'uid': '7315',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738374030,
#                                      'address': 'Queen St E / Hammersmith Ave',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 9,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': None,
#                                      'slots': 11,
#                                      'rental_uris': {}}},
#                           {'id': '068f5330e49bd7236864c7cbf904813f',
#                            'name': 'Walnut Ave / Queen St W',
#                            'latitude': 43.645469,
#                            'longitude': -79.411084,
#                            'timestamp': '2025-02-01T01:41:37.949614Z',
#                            'free_bikes': 6,
#                            'empty_slots': 9,
#                            'extra': {'uid': '7534',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738374015,
#                                      'address': 'Walnut Ave / Queen St W',
#                                      'post_code': 'M6J 1G4',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 6,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': 0.0,
#                                      'slots': 15,
#                                      'rental_uris': {}}},
#                           {'id': '0690f86b4ecb172570d8e08b5f9004c3',
#                            'name': 'Queen St E / Pape Ave - SMART',
#                            'latitude': 43.661673,
#                            'longitude': -79.337789,
#                            'timestamp': '2025-02-01T01:41:37.947132Z',
#                            'free_bikes': 12,
#                            'empty_slots': 3,
#                            'extra': {'uid': '7287',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373969,
#                                      'address': 'Queen St E / Pape Ave',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 12,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'altitude': None,
#                                      'slots': 15,
#                                      'rental_uris': {}}},
#                           {'id': '06dd97607037897ed24979d9b9cd4bed',
#                            'name': 'Tecumseth St / Tecumseth Pl',
#                            'latitude': 43.642697996199985,
#                            'longitude': -79.4049993694586,
#                            'timestamp': '2025-02-01T01:41:37.962256Z',
#                            'free_bikes': 4,
#                            'empty_slots': 6,
#                            'extra': {'uid': '8003',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373932,
#                                      'address': 'Tecumseth St / Tecumseth Pl',
#                                      'post_code': 'M5V 2R8',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 4,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'altitude': 0.0,
#                                      'slots': 11,
#                                      'rental_uris': {}}},
#                           {'id': '071b427d1f3f600d6b9f35ca6576ebe2',
#                            'name': 'Davenport Rd / Lansdowne Ave',
#                            'latitude': 43.671526,
#                            'longitude': -79.44874,
#                            'timestamp': '2025-02-01T01:41:37.947565Z',
#                            'free_bikes': 3,
#                            'empty_slots': 16,
#                            'extra': {'uid': '7326',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738374028,
#                                      'address': 'Davenport Rd / Landsdowne Rd',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 3,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': None,
#                                      'slots': 19,
#                                      'rental_uris': {}}},
#                           {'id': '0729b25bcf663b7a2278f01d63b50fcf',
#                            'name': 'Eastwood Rd / Coxwell Ave',
#                            'latitude': 43.673118,
#                            'longitude': -79.318651,
#                            'timestamp': '2025-02-01T01:41:37.948846Z',
#                            'free_bikes': 12,
#                            'empty_slots': 7,
#                            'extra': {'uid': '7445',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373999,
#                                      'address': 'Eastwood Rd / Coxwell Ave',
#                                      'post_code': 'M4L 3B5',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 12,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': None,
#                                      'slots': 19,
#                                      'rental_uris': {}}},
#                           {'id': '07bf4729ad15e9e2d17d072dfb67e6b0',
#                            'name': 'Fenwood Ht / Kingston Rd',
#                            'latitude': 43.72690169821676,
#                            'longitude': -79.22920396582664,
#                            'timestamp': '2025-02-01T01:41:37.960143Z',
#                            'free_bikes': 2,
#                            'empty_slots': 13,
#                            'extra': {'uid': '7814',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373920,
#                                      'address': 'Fenwood Ht / Kingston Rd',
#                                      'post_code': 'M1M 1P1',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 2,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'altitude': 0.0,
#                                      'slots': 15,
#                                      'rental_uris': {}}},
#                           {'id': '07c0bbd2b5c108bacb3a32250af2a076',
#                            'name': 'Rouge Hill GO Station',
#                            'latitude': 43.7805505,
#                            'longitude': -79.1301203,
#                            'timestamp': '2025-02-01T01:41:37.950610Z',
#                            'free_bikes': 21,
#                            'empty_slots': 4,
#                            'extra': {'uid': '7626',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373969,
#                                      'address': 'Rouge Hill GO Station',
#                                      'post_code': 'M1C 5G4',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 21,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': 0.0,
#                                      'slots': 25,
#                                      'rental_uris': {}}},
#                           {'id': '080c6cc1f827d976fd75f9ccf53db95c',
#                            'name': 'Lundy Ave / Étienne Brûlé Park',
#                            'latitude': 43.6625395,
#                            'longitude': -79.5030161,
#                            'timestamp': '2025-02-01T01:41:37.950633Z',
#                            'free_bikes': 6,
#                            'empty_slots': 9,
#                            'extra': {'uid': '7629',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373952,
#                                      'address': 'Lundy Ave / Etienne Brule '
#                                                 'Park',
#                                      'post_code': 'M6S 2R5',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 6,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': 0.0,
#                                      'slots': 15,
#                                      'rental_uris': {}}},
#                           {'id': '082fdb9cce172f916dde26cc3a543b69',
#                            'name': 'Bremner Blvd / Rees St',
#                            'latitude': 43.641529,
#                            'longitude': -79.386741,
#                            'timestamp': '2025-02-01T01:41:37.944275Z',
#                            'free_bikes': 47,
#                            'empty_slots': 2,
#                            'extra': {'uid': '7018',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373945,
#                                      'address': 'Bremner Blvd / Rees St',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 47,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': None,
#                                      'slots': 49,
#                                      'rental_uris': {}}},
#                           {'id': '084dc489a2da0c722c17a379c243a12a',
#                            'name': 'Willowdale Ave / Bishop Ave ',
#                            'latitude': 43.78387252467251,
#                            'longitude': -79.40786809814757,
#                            'timestamp': '2025-02-01T01:41:37.961719Z',
#                            'free_bikes': 7,
#                            'empty_slots': 11,
#                            'extra': {'uid': '7970',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373953,
#                                      'address': 'Willowdale Ave / Bishop Ave ',
#                                      'post_code': 'M2M 3C2',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 7,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'altitude': 0.0,
#                                      'slots': 19,
#                                      'rental_uris': {}}},
#                           {'id': '086ae84908444d2c0d0faf35deb1704f',
#                            'name': 'Plaxton Dr / St Clair Ave E',
#                            'latitude': 43.70751755961952,
#                            'longitude': -79.30252066313936,
#                            'timestamp': '2025-02-01T01:41:37.960302Z',
#                            'free_bikes': 2,
#                            'empty_slots': 12,
#                            'extra': {'uid': '7830',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738374038,
#                                      'address': 'Plaxton Dr / St Clair Ave E',
#                                      'post_code': 'M4B 1N5',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 2,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'altitude': 0.0,
#                                      'slots': 14,
#                                      'rental_uris': {}}},
#                           {'id': '08b57a79795bbd49a15e4a3692ee924f',
#                            'name': 'Front St W / University Ave (2)',
#                            'latitude': 43.6452972,
#                            'longitude': -79.3827914,
#                            'timestamp': '2025-02-01T01:41:37.947509Z',
#                            'free_bikes': 17,
#                            'empty_slots': 0,
#                            'extra': {'uid': '7321',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738374035,
#                                      'address': 'Front St W / University Ave '
#                                                 '(2)',
#                                      'has_ebikes': True,
#                                      'ebikes': 1,
#                                      'normal_bikes': 16,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': None,
#                                      'slots': 19,
#                                      'rental_uris': {}}},
#                           {'id': '08d867cbed5f08addb01b714700eacf7',
#                            'name': 'Jarvis St / Richmond St E',
#                            'latitude': 43.652777,
#                            'longitude': -79.372637,
#                            'timestamp': '2025-02-01T01:41:37.949114Z',
#                            'free_bikes': 3,
#                            'empty_slots': 16,
#                            'extra': {'uid': '7475',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373928,
#                                      'address': 'Jarvis St / Richmond St E',
#                                      'post_code': 'M5C 2H6',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 3,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': None,
#                                      'slots': 19,
#                                      'rental_uris': {}}},
#                           {'id': '09007b5f868cd54be0f040f9a9a75c42',
#                            'name': 'Mortimer Ave / Coxwell Ave',
#                            'latitude': 43.690564,
#                            'longitude': -79.326319,
#                            'timestamp': '2025-02-01T01:41:37.946008Z',
#                            'free_bikes': 7,
#                            'empty_slots': 15,
#                            'extra': {'uid': '7194',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738374070,
#                                      'address': 'Mortimer Ave / Coxwell Ave',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 7,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': None,
#                                      'slots': 23,
#                                      'rental_uris': {}}},
#                           {'id': '092cb5f641f627d7b43e321542ccc066',
#                            'name': 'Dundas St E / River St',
#                            'latitude': 43.661152,
#                            'longitude': -79.358505,
#                            'timestamp': '2025-02-01T01:41:37.959970Z',
#                            'free_bikes': 6,
#                            'empty_slots': 12,
#                            'extra': {'uid': '7796',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738374023,
#                                      'address': 'Dundas St E / River St',
#                                      'has_ebikes': True,
#                                      'ebikes': 1,
#                                      'normal_bikes': 5,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'altitude': 0.0,
#                                      'slots': 18,
#                                      'rental_uris': {}}},
#                           {'id': '0a28cd61ad950b8ebc49d08f1b3936ee',
#                            'name': 'St Clair Ave W / Symes Rd',
#                            'latitude': 43.670042134416704,
#                            'longitude': -79.4789424818056,
#                            'timestamp': '2025-02-01T01:41:37.961058Z',
#                            'free_bikes': 2,
#                            'empty_slots': 12,
#                            'extra': {'uid': '7903',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738374015,
#                                      'address': '2236 St Clair Ave W',
#                                      'post_code': 'M6N 5C1',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 2,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'altitude': 0.0,
#                                      'slots': 15,
#                                      'rental_uris': {}}},
#                           {'id': '0abdfc3177000757dcd71bd4c8b479ee',
#                            'name': 'Yarmouth Rd / Christie St',
#                            'latitude': 43.67,
#                            'longitude': -79.42083333333333,
#                            'timestamp': '2025-02-01T01:41:37.945565Z',
#                            'free_bikes': 1,
#                            'empty_slots': 9,
#                            'extra': {'uid': '7149',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373987,
#                                      'address': 'Yarmouth Rd / Christie St',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 1,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': None,
#                                      'slots': 11,
#                                      'rental_uris': {}}},
#                           {'id': '0ac5489c6a4750403c053598153880b0',
#                            'name': 'Dufferin Gate - SMART',
#                            'latitude': 43.633473,
#                            'longitude': -79.425679,
#                            'timestamp': '2025-02-01T01:41:37.946584Z',
#                            'free_bikes': 5,
#                            'empty_slots': 11,
#                            'extra': {'uid': '7244',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373939,
#                                      'address': 'Dufferin Gate',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 5,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'altitude': None,
#                                      'slots': 16,
#                                      'rental_uris': {}}},
#                           {'id': '0b153cb4fe7873b109e3068cf99dbf74',
#                            'name': 'Symington Ave / Davenport Rd',
#                            'latitude': 43.6704403,
#                            'longitude': -79.45328549999999,
#                            'timestamp': '2025-02-01T01:41:37.949566Z',
#                            'free_bikes': 2,
#                            'empty_slots': 13,
# ...
#                            'free_bikes': 15,
#                            'empty_slots': 8,
#                            'extra': {'uid': '7164',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373926,
#                                      'address': 'Gould St / Yonge St (Ryerson '
#                                                 'University)',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 15,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': None,
#                                      'slots': 23,
#                                      'rental_uris': {}}},
#                           {'id': 'fc6389e5eba6c99ed3c0185b65c9cb5c',
#                            'name': '406 Oakwood Ave',
#                            'latitude': 43.68827060022711,
#                            'longitude': -79.43937767081853,
#                            'timestamp': '2025-02-01T01:41:37.949460Z',
#                            'free_bikes': 0,
#                            'empty_slots': 19,
#                            'extra': {'uid': '7519',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738374017,
#                                      'address': '406 Oakwood Ave, York, ON M6E '
#                                                 '2W3',
#                                      'post_code': 'L5C 1E4',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 0,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': 0.0,
#                                      'slots': 19,
#                                      'rental_uris': {}}},
#                           {'id': 'fc7fa6476f3fce587eeb9e2200faa005',
#                            'name': 'Simcoe St / Queen St W',
#                            'latitude': 43.65049,
#                            'longitude': -79.3873,
#                            'timestamp': '2025-02-01T01:41:37.944318Z',
#                            'free_bikes': 36,
#                            'empty_slots': 3,
#                            'extra': {'uid': '7022',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373987,
#                                      'address': 'Simcoe St / Queen St W',
#                                      'post_code': 'm5v1z5',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 36,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': None,
#                                      'slots': 39,
#                                      'rental_uris': {}}},
#                           {'id': 'fca601c1041c34a9c42af38d71e7403a',
#                            'name': 'Cherry Beach Sports Fields (55 Unwin Ave)',
#                            'latitude': 43.6408346,
#                            'longitude': -79.3429074,
#                            'timestamp': '2025-02-01T01:41:37.947756Z',
#                            'free_bikes': 16,
#                            'empty_slots': 15,
#                            'extra': {'uid': '7345',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373962,
#                                      'address': 'Cherry Beach Sports Field (55 '
#                                                 'Unwin Ave)',
#                                      'post_code': 'M5A 1A3',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 16,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': None,
#                                      'slots': 31,
#                                      'rental_uris': {}}},
#                           {'id': 'fd7c0cadeb907434f002aadc42a88554',
#                            'name': 'Brimley Rd / Lawrence Ave E ',
#                            'latitude': 43.75404854399297,
#                            'longitude': -79.2553167552948,
#                            'timestamp': '2025-02-01T01:41:37.961586Z',
#                            'free_bikes': 1,
#                            'empty_slots': 37,
#                            'extra': {'uid': '7957',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738374004,
#                                      'address': '925 Brimley Rd',
#                                      'post_code': 'M1P 3E8',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 1,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'altitude': 0.0,
#                                      'slots': 39,
#                                      'rental_uris': {}}},
#                           {'id': 'fe00988a883c9469b82d17221ef1824b',
#                            'name': 'Dundas St W / Roncesvalles Ave Green P '
#                                    '-SMART',
#                            'latitude': 43.6534268,
#                            'longitude': -79.4512787,
#                            'timestamp': '2025-02-01T01:41:37.946420Z',
#                            'free_bikes': 1,
#                            'empty_slots': 10,
#                            'extra': {'uid': '7229',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373939,
#                                      'address': 'Dundas St W / Roncesvalles '
#                                                 'Green P',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 1,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'altitude': None,
#                                      'slots': 12,
#                                      'rental_uris': {}}},
#                           {'id': 'fe268f3f2f439d0016dc46605491078e',
#                            'name': 'Pottery Rd / Lower Don River Trail',
#                            'latitude': 43.688148,
#                            'longitude': -79.362101,
#                            'timestamp': '2025-02-01T01:41:37.948936Z',
#                            'free_bikes': 11,
#                            'empty_slots': 3,
#                            'extra': {'uid': '7454',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373909,
#                                      'address': 'Pottery Rd / Lower Don River '
#                                                 'Trail',
#                                      'post_code': 'M4K 2B9',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 11,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': None,
#                                      'slots': 15,
#                                      'rental_uris': {}}},
#                           {'id': 'fe806cf907683c67f4d2899eb4123f00',
#                            'name': '457 King St W',
#                            'latitude': 43.6452091,
#                            'longitude': -79.3960744,
#                            'timestamp': '2025-02-01T01:41:37.947539Z',
#                            'free_bikes': 15,
#                            'empty_slots': 2,
#                            'extra': {'uid': '7323',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738374074,
#                                      'address': '457 King St W.',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 15,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': None,
#                                      'slots': 19,
#                                      'rental_uris': {}}},
#                           {'id': 'fe97ae335b31b6c455f340f397904d38',
#                            'name': 'Danforth Ave / Coxwell Ave',
#                            'latitude': 43.683378,
#                            'longitude': -79.322961,
#                            'timestamp': '2025-02-01T01:41:37.944943Z',
#                            'free_bikes': 5,
#                            'empty_slots': 10,
#                            'extra': {'uid': '7088',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373947,
#                                      'address': 'Danforth Ave / Coxwell Ave',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 5,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': 0.0,
#                                      'slots': 15,
#                                      'rental_uris': {}}},
#                           {'id': 'fea3f9dfbcc18225728f10913c5d3d5b',
#                            'name': 'Bloor St W / Brock Ave',
#                            'latitude': 43.6589882,
#                            'longitude': -79.438715,
#                            'timestamp': '2025-02-01T01:41:37.958056Z',
#                            'free_bikes': 3,
#                            'empty_slots': 8,
#                            'extra': {'uid': '7656',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738374004,
#                                      'address': 'Bloor St W / Brock Av',
#                                      'post_code': 'M6H 1M9',
#                                      'has_ebikes': True,
#                                      'ebikes': 1,
#                                      'normal_bikes': 2,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': 0.0,
#                                      'slots': 11,
#                                      'rental_uris': {}}},
#                           {'id': 'ffc954e6f4228f59169c040483ebcc3a',
#                            'name': 'Wells Hill Ave / St Clair Ave W',
#                            'latitude': 43.683351,
#                            'longitude': -79.41562,
#                            'timestamp': '2025-02-01T01:41:37.948110Z',
#                            'free_bikes': 0,
#                            'empty_slots': 15,
#                            'extra': {'uid': '7363',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738373931,
#                                      'address': 'Wells Hill Ave / St Clair Ave '
#                                                 'W',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 0,
#                                      'payment': ['key',
#                                                  'transitcard',
#                                                  'creditcard',
#                                                  'phone'],
#                                      'payment-terminal': True,
#                                      'altitude': None,
#                                      'slots': 15,
#                                      'rental_uris': {}}},
#                           {'id': 'ffeaa2aaedeb18fc11f708bcd8323149',
#                            'name': 'Bay St / Dundas St W',
#                            'latitude': 43.655350778457056,
#                            'longitude': -79.38345966759798,
#                            'timestamp': '2025-02-01T01:41:37.960163Z',
#                            'free_bikes': 40,
#                            'empty_slots': 14,
#                            'extra': {'uid': '7816',
#                                      'renting': 1,
#                                      'returning': 1,
#                                      'last_updated': 1738374010,
#                                      'address': 'Bay St / Dundas St W',
#                                      'post_code': 'M5G 2C3',
#                                      'has_ebikes': True,
#                                      'ebikes': 0,
#                                      'normal_bikes': 40,
#                                      'payment': ['key', 'transitcard', 'phone'],
#                                      'payment-terminal': False,
#                                      'altitude': 0.0,
#                                      'slots': 55,
#                                      'rental_uris': {}}}]}}

# %% [markdown]
# Put your parsed results into a DataFrame.

# %%
normalised = pd.json_normalize(data,record_path = ['network', 'stations'])
bikes_df = pd.DataFrame(normalised)
bikes_df
# Out:
#                                    id                              name  \
# 0    009f180cf35ae1285733d98ccf058313    Summerhill Ave / Maclennan Ave
# 1    010507feed5b8d87c40cd95933ed5654     Queen St E / Joseph Duggan Rd
# 2    0153756b9e136b96e730aaa2f048227f  Victoria Park Ave / Danforth Ave
# 3    019e5937c3fc120cee906770bca8fa69     Navy Wharf Crt / Bremner Blvd
# 4    01caf8b12874b091f2fccc3818e3c72e               420 Wellington St W
# ..                                ...                               ...
# 859  fe806cf907683c67f4d2899eb4123f00                     457 King St W
# 860  fe97ae335b31b6c455f340f397904d38        Danforth Ave / Coxwell Ave
# 861  fea3f9dfbcc18225728f10913c5d3d5b            Bloor St W / Brock Ave
# 862  ffc954e6f4228f59169c040483ebcc3a   Wells Hill Ave / St Clair Ave W
# 863  ffeaa2aaedeb18fc11f708bcd8323149              Bay St / Dundas St W
#
#       latitude  longitude                    timestamp  free_bikes  \
# 0    43.685924 -79.376304  2025-02-01T01:41:37.949238Z           0
# 1    43.667763 -79.308117  2025-02-01T01:41:37.958366Z          11
# 2    43.691468 -79.288619  2025-02-01T01:41:37.950454Z           2
# 3    43.640722 -79.391051  2025-02-01T01:41:37.944663Z           8
# 4    43.643834 -79.396649  2025-02-01T01:41:37.945317Z          10
# ..         ...        ...                          ...         ...
# 859  43.645209 -79.396074  2025-02-01T01:41:37.947539Z          15
# 860  43.683378 -79.322961  2025-02-01T01:41:37.944943Z           5
# 861  43.658988 -79.438715  2025-02-01T01:41:37.958056Z           3
# 862  43.683351 -79.415620  2025-02-01T01:41:37.948110Z           0
# 863  43.655351 -79.383460  2025-02-01T01:41:37.960163Z          40
#
#      empty_slots extra.uid  extra.renting  extra.returning  \
# 0              8      7488              1                1
# 1              7      7695              1                1
# 2             17      7611              1                1
# 3              0      7054              1                1
# 4              2      7123              1                1
# ..           ...       ...            ...              ...
# 859            2      7323              1                1
# 860           10      7088              1                1
# 861            8      7656              1                1
# 862           15      7363              1                1
# 863           14      7816              1                1
#
#      extra.last_updated                     extra.address extra.post_code  \
# 0            1738373920    Summerhill Ave / Maclennan Ave         M4M 2Z9
# 1            1738374000   Queen St E and Joseph Duggan Rd         M4L 3Y2
# 2            1738373938  Victoria Park Ave / Danforth Ave         M4C 1N2
# 3            1738374080    Navy Wharf Ct. / Bremner Blvd.             NaN
# 4            1738373992               420 Wellington St W             NaN
# ..                  ...                               ...             ...
# 859          1738374074                    457 King St W.             NaN
# 860          1738373947        Danforth Ave / Coxwell Ave             NaN
# 861          1738374004             Bloor St W / Brock Av         M6H 1M9
# 862          1738373931   Wells Hill Ave / St Clair Ave W             NaN
# 863          1738374010              Bay St / Dundas St W         M5G 2C3
#
#      extra.has_ebikes  extra.ebikes  extra.normal_bikes  \
# 0                True             0                   0
# 1                True             2                   9
# 2                True             0                   2
# 3                True             0                   8
# 4                True             0                  10
# ..                ...           ...                 ...
# 859              True             0                  15
# 860              True             0                   5
# 861              True             1                   2
# 862              True             0                   0
# 863              True             0                  40
#
#                              extra.payment  extra.payment-terminal  \
# 0    [key, transitcard, creditcard, phone]                    True
# 1                [key, transitcard, phone]                   False
# 2    [key, transitcard, creditcard, phone]                    True
# 3    [key, transitcard, creditcard, phone]                    True
# 4    [key, transitcard, creditcard, phone]                    True
# ..                                     ...                     ...
# 859  [key, transitcard, creditcard, phone]                    True
# 860  [key, transitcard, creditcard, phone]                    True
# 861  [key, transitcard, creditcard, phone]                    True
# 862  [key, transitcard, creditcard, phone]                    True
# 863              [key, transitcard, phone]                   False
#
#      extra.altitude  extra.slots
# 0               NaN           11
# 1               0.0           19
# 2               0.0           19
# 3               NaN            9
# 4               NaN           14
# ..              ...          ...
# 859             NaN           19
# 860             0.0           15
# 861             0.0           11
# 862             NaN           15
# 863             0.0           55
#
# [864 rows x 20 columns]

# %%
bikes_df = bikes_df.rename(columns={'extra.slots':'number_of_bikes'})

# %%
columns = list(bikes_df)
columns_to_drop = [i for i in columns if i.startswith('extra')]
columns_to_drop.extend(['timestamp','free_bikes', 'empty_slots'])
bike_stations = bikes_df.drop(columns = columns_to_drop)

# %%
bike_stations
# Out:
#                                    id                              name  \
# 0    009f180cf35ae1285733d98ccf058313    Summerhill Ave / Maclennan Ave
# 1    010507feed5b8d87c40cd95933ed5654     Queen St E / Joseph Duggan Rd
# 2    0153756b9e136b96e730aaa2f048227f  Victoria Park Ave / Danforth Ave
# 3    019e5937c3fc120cee906770bca8fa69     Navy Wharf Crt / Bremner Blvd
# 4    01caf8b12874b091f2fccc3818e3c72e               420 Wellington St W
# ..                                ...                               ...
# 859  fe806cf907683c67f4d2899eb4123f00                     457 King St W
# 860  fe97ae335b31b6c455f340f397904d38        Danforth Ave / Coxwell Ave
# 861  fea3f9dfbcc18225728f10913c5d3d5b            Bloor St W / Brock Ave
# 862  ffc954e6f4228f59169c040483ebcc3a   Wells Hill Ave / St Clair Ave W
# 863  ffeaa2aaedeb18fc11f708bcd8323149              Bay St / Dundas St W
#
#       latitude  longitude  number_of_bikes
# 0    43.685924 -79.376304               11
# 1    43.667763 -79.308117               19
# 2    43.691468 -79.288619               19
# 3    43.640722 -79.391051                9
# 4    43.643834 -79.396649               14
# ..         ...        ...              ...
# 859  43.645209 -79.396074               19
# 860  43.683378 -79.322961               15
# 861  43.658988 -79.438715               11
# 862  43.683351 -79.415620               15
# 863  43.655351 -79.383460               55
#
# [864 rows x 5 columns]

# %%
bike_stations.to_csv('../data/toronto_bike_stations.csv')
