# %%
# imports
import requests
import os
import pandas as pd
import numpy as np
import pprint
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
fs_key = os.getenv('FOURSQUARE_API_KEY')

# %%
''' Categories
10000	Arts and Entertainment
12009	Community and Government > Education
13003	Dining and Drinking > Bar
13065	Dining and Drinking > Restaurant
16032	Landmarks and Outdoors > Park
16019	Landmarks and Outdoors > Hiking Trail
17114	Retail > Shopping Mall
18000	Sports and Recreation
19030	Travel and Transportation > Transport Hub
'''
categories = '10000,12009,13003,13065,16032,16019,17114,18000,19030'

# %%
def get_venues_fs(latitude, longitude, radius, api_key, categories):
    
    url = f'https://api.foursquare.com/v3/places/search?ll={latitude}%2C{longitude}&radius={radius}&categories={categories}'

    headers = {'accept': 'application/json'}
    headers['Authorization'] = api_key
        
    response = requests.get(url, headers=headers)
    response_data = response.json()
    return response_data

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
test_fs = get_venues_fs(latitude=43.685924, longitude=-79.376304, radius=1000, api_key=fs_key, categories=categories)
pprint.pp(test_fs)
# Out:
# {'results': [{'fsq_id': '4ae48f90f964a520ad9b21e3',
#               'categories': [{'id': 16032,
#                               'name': 'Park',
#                               'short_name': 'Park',
#                               'plural_name': 'Parks',
#                               'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#                                        'suffix': '.png'}}],
#               'chains': [],
#               'closed_bucket': 'LikelyOpen',
#               'distance': 470,
#               'geocodes': {'main': {'latitude': 43.687377,
#                                     'longitude': -79.370803},
#                            'roof': {'latitude': 43.687377,
#                                     'longitude': -79.370803}},
#               'link': '/v3/places/4ae48f90f964a520ad9b21e3',
#               'location': {'address': '250 Douglas Dr',
#                            'country': 'CA',
#                            'cross_street': 'Glenn Rd.(Summerhill Av.)',
#                            'formatted_address': '250 Douglas Dr (Glenn '
#                                                 'Rd.(Summerhill Av.)), Toronto '
#                                                 'ON M4W 2C1',
#                            'locality': 'Toronto',
#                            'postcode': 'M4W 2C1',
#                            'region': 'ON'},
#               'name': 'Chorley Park',
#               'related_places': {},
#               'timezone': 'America/Toronto'},
#              {'fsq_id': '4dfe2ca5185009bba4df0608',
#               'categories': [{'id': 16032,
#                               'name': 'Park',
#                               'short_name': 'Park',
#                               'plural_name': 'Parks',
#                               'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#                                        'suffix': '.png'}}],
#               'chains': [],
#               'closed_bucket': 'LikelyOpen',
#               'distance': 905,
#               'geocodes': {'main': {'latitude': 43.684526,
#                                     'longitude': -79.365204},
#                            'roof': {'latitude': 43.684526,
#                                     'longitude': -79.365204}},
#               'link': '/v3/places/4dfe2ca5185009bba4df0608',
#               'location': {'address': '550 Bayview Ave',
#                            'country': 'CA',
#                            'formatted_address': '550 Bayview Ave, Toronto ON '
#                                                 'M4W 3X8',
#                            'locality': 'Toronto',
#                            'postcode': 'M4W 3X8',
#                            'region': 'ON'},
#               'name': 'The Don Valley Brick Works Park',
#               'related_places': {},
#               'timezone': 'America/Toronto'},
#              {'fsq_id': '4bf031dcf831c928eab401f2',
#               'categories': [{'id': 16032,
#                               'name': 'Park',
#                               'short_name': 'Park',
#                               'plural_name': 'Parks',
#                               'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#                                        'suffix': '.png'}},
#                              {'id': 18000,
#                               'name': 'Sports and Recreation',
#                               'short_name': 'Sports and Recreation',
#                               'plural_name': 'Sports and Recreation',
#                               'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#                                        'suffix': '.png'}}],
#               'chains': [],
#               'closed_bucket': 'VeryLikelyOpen',
#               'distance': 960,
#               'geocodes': {'main': {'latitude': 43.685607,
#                                     'longitude': -79.388253},
#                            'roof': {'latitude': 43.685607,
#                                     'longitude': -79.388253}},
#               'link': '/v3/places/4bf031dcf831c928eab401f2',
#               'location': {'address': '200 Mount Pleasant Rd',
#                            'country': 'CA',
#                            'formatted_address': '200 Mount Pleasant Rd, '
#                                                 'Toronto ON M4T 2C4',
#                            'locality': 'Toronto',
#                            'postcode': 'M4T 2C4',
#                            'region': 'ON'},
#               'name': 'David A. Balfour Park',
#               'related_places': {'children': []},
#               'timezone': 'America/Toronto'},
#              {'fsq_id': '4dfe2d6d185009bba4df0672',
#               'categories': [{'id': 16032,
#                               'name': 'Park',
#                               'short_name': 'Park',
#                               'plural_name': 'Parks',
#                               'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#                                        'suffix': '.png'}},
#                              {'id': 18000,
#                               'name': 'Sports and Recreation',
#                               'short_name': 'Sports and Recreation',
#                               'plural_name': 'Sports and Recreation',
#                               'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#                                        'suffix': '.png'}}],
#               'chains': [],
#               'closed_bucket': 'VeryLikelyOpen',
#               'distance': 906,
#               'geocodes': {'main': {'latitude': 43.693691,
#                                     'longitude': -79.379762},
#                            'roof': {'latitude': 43.693691,
#                                     'longitude': -79.379762}},
#               'link': '/v3/places/4dfe2d6d185009bba4df0672',
#               'location': {'address': '205 Moore Ave',
#                            'country': 'CA',
#                            'formatted_address': '205 Moore Ave, Toronto ON M4T '
#                                                 '2K7',
#                            'locality': 'Toronto',
#                            'postcode': 'M4T 2K7',
#                            'region': 'ON'},
#               'name': 'Moore Park Ravine',
#               'related_places': {'children': []},
#               'timezone': 'America/Toronto'},
#              {'fsq_id': '4bc0d290920eb713dda1192c',
#               'categories': [{'id': 16032,
#                               'name': 'Park',
#                               'short_name': 'Park',
#                               'plural_name': 'Parks',
#                               'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#                                        'suffix': '.png'}}],
#               'chains': [],
#               'closed_bucket': 'LikelyOpen',
#               'distance': 984,
#               'geocodes': {'main': {'latitude': 43.68626,
#                                     'longitude': -79.388544}},
#               'link': '/v3/places/4bc0d290920eb713dda1192c',
#               'location': {'address': '75 Rosehill Ave',
#                            'country': 'CA',
#                            'cross_street': '',
#                            'formatted_address': '75 Rosehill Ave, Toronto ON',
#                            'locality': 'Toronto',
#                            'region': 'ON'},
#               'name': 'Rosehill Reservoir',
#               'related_places': {},
#               'timezone': 'America/Toronto'},
#              {'fsq_id': '4b0afc19f964a520212b23e3',
#               'categories': [{'id': 16000,
#                               'name': 'Landmarks and Outdoors',
#                               'short_name': 'Landmarks and Outdoors',
#                               'plural_name': 'Landmarks and Outdoors',
#                               'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#                                        'suffix': '.png'}},
#                              {'id': 18000,
#                               'name': 'Sports and Recreation',
#                               'short_name': 'Sports and Recreation',
#                               'plural_name': 'Sports and Recreation',
#                               'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#                                        'suffix': '.png'}}],
#               'chains': [],
#               'closed_bucket': 'LikelyOpen',
#               'distance': 4274,
#               'geocodes': {'main': {'latitude': 43.678243,
#                                     'longitude': -79.375198},
#                            'roof': {'latitude': 43.678243,
#                                     'longitude': -79.375198}},
#               'link': '/v3/places/4b0afc19f964a520212b23e3',
#               'location': {'address': '100 Glen Rd',
#                            'country': 'CA',
#                            'cross_street': 'Strathearn',
#                            'formatted_address': '100 Glen Rd (Strathearn), '
#                                                 'Toronto ON',
#                            'locality': 'Toronto',
#                            'region': 'ON'},
#               'name': 'Cedarvale Park',
#               'related_places': {'children': [{'fsq_id': '63ed3f67ddccfe65fcbe65de',
#                                                'categories': [{'id': 16019,
#                                                                'name': 'Hiking '
#                                                                        'Trail',
#                                                                'short_name': 'Trail',
#                                                                'plural_name': 'Hiking '
#                                                                               'Trails',
#                                                                'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#                                                                         'suffix': '.png'}}],
#                                                'name': 'Cedarvale Trail'},
#                                               {'fsq_id': '4c24abfcf7ced13aa425236d',
#                                                'categories': [{'id': 16000,
#                                                                'name': 'Landmarks '
#                                                                        'and '
#                                                                        'Outdoors',
#                                                                'short_name': 'Landmarks '
#                                                                              'and '
#                                                                              'Outdoors',
#                                                                'plural_name': 'Landmarks '
#                                                                               'and '
#                                                                               'Outdoors',
#                                                                'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#                                                                         'suffix': '.png'}}],
#                                                'name': 'Cedarvale Ravine'},
#                                               {'fsq_id': '61c4f0b4e565fe05c7572a44',
#                                                'categories': [{'id': 16000,
#                                                                'name': 'Landmarks '
#                                                                        'and '
#                                                                        'Outdoors',
#                                                                'short_name': 'Landmarks '
#                                                                              'and '
#                                                                              'Outdoors',
#                                                                'plural_name': 'Landmarks '
#                                                                               'and '
#                                                                               'Outdoors',
#                                                                'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#                                                                         'suffix': '.png'}}],
#                                                'name': 'Toboggan Hill'},
#                                               {'fsq_id': '5050f634e4b092c65b899303',
#                                                'categories': [{'id': 16033,
#                                                                'name': 'Dog '
#                                                                        'Park',
#                                                                'short_name': 'Dog '
#                                                                              'Park',
#                                                                'plural_name': 'Dog '
#                                                                               'Parks',
#                                                                'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#                                                                         'suffix': '.png'}}],
#                                                'name': 'Cedarvale Dog Park'}]},
#               'timezone': 'America/Toronto'},
#              {'fsq_id': '5f6f6dc999b0676341c2edd0',
#               'categories': [{'id': 13039,
#                               'name': 'Deli',
#                               'short_name': 'Deli',
#                               'plural_name': 'Delis',
#                               'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#                                        'suffix': '.png'}}],
#               'chains': [],
#               'closed_bucket': 'LikelyOpen',
#               'distance': 27,
#               'geocodes': {'drop_off': {'latitude': 43.685932,
#                                         'longitude': -79.376555},
#                            'main': {'latitude': 43.68606,
#                                     'longitude': -79.376582},
#                            'roof': {'latitude': 43.68606,
#                                     'longitude': -79.376582}},
#               'link': '/v3/places/5f6f6dc999b0676341c2edd0',
#               'location': {'address': '408 Summerhill Ave',
#                            'country': 'CA',
#                            'cross_street': '',
#                            'formatted_address': '408 Summerhill Ave, Toronto '
#                                                 'ON M4W 2E4',
#                            'locality': 'Toronto',
#                            'postcode': 'M4W 2E4',
#                            'region': 'ON'},
#               'name': "Rosedale's Finest",
#               'related_places': {},
#               'timezone': 'America/Toronto'},
#              {'fsq_id': '5f710453c2dbe370d739275e',
#               'categories': [{'id': 13002,
#                               'name': 'Bakery',
#                               'short_name': 'Bakery',
#                               'plural_name': 'Bakeries',
#                               'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#                                        'suffix': '.png'}},
#                              {'id': 13034,
#                               'name': 'Café',
#                               'short_name': 'Café',
#                               'plural_name': 'Cafés',
#                               'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#                                        'suffix': '.png'}},
#                              {'id': 13065,
#                               'name': 'Restaurant',
#                               'short_name': 'Restaurant',
#                               'plural_name': 'Restaurants',
#                               'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#                                        'suffix': '.png'}}],
#               'chains': [],
#               'closed_bucket': 'LikelyOpen',
#               'distance': 38,
#               'geocodes': {'drop_off': {'latitude': 43.686047,
#                                         'longitude': -79.37601},
#                            'main': {'latitude': 43.686211,
#                                     'longitude': -79.376045},
#                            'roof': {'latitude': 43.686211,
#                                     'longitude': -79.376045}},
#               'link': '/v3/places/5f710453c2dbe370d739275e',
#               'location': {'address': '420 Summerhill Ave',
#                            'country': 'CA',
#                            'cross_street': '',
#                            'formatted_address': '420 Summerhill Ave, Toronto '
#                                                 'ON M4W 2E4',
#                            'locality': 'Toronto',
#                            'postcode': 'M4W 2E4',
#                            'region': 'ON'},
#               'name': 'Dolce Bakery',
#               'related_places': {},
#               'timezone': 'America/Toronto'},
#              {'fsq_id': '521f6410498e94a0abedbf5e',
#               'categories': [{'id': 16032,
#                               'name': 'Park',
#                               'short_name': 'Park',
#                               'plural_name': 'Parks',
#                               'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#                                        'suffix': '.png'}}],
#               'chains': [],
#               'closed_bucket': 'LikelyOpen',
#               'distance': 195,
#               'geocodes': {'drop_off': {'latitude': 43.685858,
#                                         'longitude': -79.378693},
#                            'main': {'latitude': 43.686017,
#                                     'longitude': -79.378727}},
#               'link': '/v3/places/521f6410498e94a0abedbf5e',
#               'location': {'address': 'Carstowe Rd',
#                            'country': 'CA',
#                            'cross_street': '',
#                            'formatted_address': 'Carstowe Rd, Toronto ON',
#                            'locality': 'Toronto',
#                            'region': 'ON'},
#               'name': 'Carstowe Road Lands',
#               'related_places': {},
#               'timezone': 'America/Toronto'},
#              {'fsq_id': '4af1feaff964a520ffe421e3',
#               'categories': [{'id': 12058,
#                               'name': 'Elementary School',
#                               'short_name': 'Elementary School',
#                               'plural_name': 'Elementary Schools',
#                               'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#                                        'suffix': '.png'}}],
#               'chains': [],
#               'closed_bucket': 'LikelyOpen',
#               'distance': 204,
#               'geocodes': {'main': {'latitude': 43.687181,
#                                     'longitude': -79.378164},
#                            'roof': {'latitude': 43.687181,
#                                     'longitude': -79.378164}},
#               'link': '/v3/places/4af1feaff964a520ffe421e3',
#               'location': {'address': '119 Rosedale Heights Dr',
#                            'country': 'CA',
#                            'formatted_address': '119 Rosedale Heights Dr, '
#                                                 'Toronto ON M4T 1C7',
#                            'locality': 'Toronto',
#                            'postcode': 'M4T 1C7',
#                            'region': 'ON'},
#               'name': 'Whitney PS',
#               'related_places': {},
#               'timezone': 'America/Toronto'}],
#  'context': {'geo_bounds': {'circle': {'center': {'latitude': 43.685924,
#                                                   'longitude': -79.376304},
#                                        'radius': 1000}}}}

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
# We need the bike_stations df so that can we search for venues close to each station
bike_stations = pd.read_csv('../data/toronto_bike_stations.csv', index_col=0)

# %%
fs_df = pd.DataFrame()
for index, row in bike_stations.iterrows():
    fs_venues = get_venues_fs(latitude=row['latitude'], longitude=row['longitude'], radius=1000, api_key=fs_key, categories=categories)
    temp_df = pd.json_normalize(fs_venues, record_path=['results'])
    temp_df['station_id'] = row['id']
    fs_df = pd.concat([fs_df, temp_df], ignore_index=True)

# %%
# I created a pickle of the dataframe while working on the code so that I could restart if I made a mistake, without having to call the API again
fs_df = pd.read_pickle('../data/foursquare.pkl')

# %% [markdown]
# + confirming that the dataframe was created correctly

# %%
print(fs_df.shape)
print(fs_df.columns)
# Out:
# (8640, 30)
# Index(['fsq_id', 'categories', 'chains', 'closed_bucket', 'distance', 'link',
#        'name', 'timezone', 'geocodes.main.latitude', 'geocodes.main.longitude',
#        'geocodes.roof.latitude', 'geocodes.roof.longitude', 'location.address',
#        'location.country', 'location.cross_street',
#        'location.formatted_address', 'location.locality', 'location.postcode',
#        'location.region', 'related_places.children',
#        'geocodes.drop_off.latitude', 'geocodes.drop_off.longitude',
#        'station_id', 'related_places.parent.fsq_id',
#        'related_places.parent.categories', 'related_places.parent.name',
#        'location.address_extended', 'location.po_box',
#        'geocodes.front_door.latitude', 'geocodes.front_door.longitude'],
#       dtype='object')

# %%
fs_df
# Out:
#                         fsq_id  \
# 0     4ae48f90f964a520ad9b21e3
# 1     4dfe2ca5185009bba4df0608
# 2     4bf031dcf831c928eab401f2
# 3     4dfe2d6d185009bba4df0672
# 4     4bc0d290920eb713dda1192c
# ...                        ...
# 8635  4ad4c061f964a520b3f720e3
# 8636  4adc9148f964a520512d21e3
# 8637  55a9bbf9498e00ffd7f4c71f
# 8638  4adbbae6f964a520402a21e3
# 8639  4ad4c062f964a520e5f720e3
#
#                                              categories  \
# 0     [{'id': 16032, 'name': 'Park', 'short_name': '...
# 1     [{'id': 16032, 'name': 'Park', 'short_name': '...
# 2     [{'id': 16032, 'name': 'Park', 'short_name': '...
# 3     [{'id': 16032, 'name': 'Park', 'short_name': '...
# 4     [{'id': 16032, 'name': 'Park', 'short_name': '...
# ...                                                 ...
# 8635  [{'id': 10037, 'name': 'Concert Hall', 'short_...
# 8636  [{'id': 13145, 'name': 'Fast Food Restaurant',...
# 8637  [{'id': 13305, 'name': 'Burrito Restaurant', '...
# 8638  [{'id': 10024, 'name': 'Movie Theater', 'short...
# 8639  [{'id': 10039, 'name': 'Music Venue', 'short_n...
#
#                                                  chains   closed_bucket  \
# 0                                                    []      LikelyOpen
# 1                                                    []      LikelyOpen
# 2                                                    []  VeryLikelyOpen
# 3                                                    []  VeryLikelyOpen
# 4                                                    []      LikelyOpen
# ...                                                 ...             ...
# 8635                                                 []      LikelyOpen
# 8636  [{'id': 'ab4c58e0-d68a-012e-5619-003048cad9da'...  VeryLikelyOpen
# 8637  [{'id': '2d108fae-d80a-482b-a105-57ab79c2581e'...  VeryLikelyOpen
# 8638                                                 []      LikelyOpen
# 8639                                                 []  VeryLikelyOpen
#
#       distance                                 link  \
# 0          470  /v3/places/4ae48f90f964a520ad9b21e3
# 1          905  /v3/places/4dfe2ca5185009bba4df0608
# 2          960  /v3/places/4bf031dcf831c928eab401f2
# 3          906  /v3/places/4dfe2d6d185009bba4df0672
# 4          984  /v3/places/4bc0d290920eb713dda1192c
# ...        ...                                  ...
# 8635       389  /v3/places/4ad4c061f964a520b3f720e3
# 8636       264  /v3/places/4adc9148f964a520512d21e3
# 8637       410  /v3/places/55a9bbf9498e00ffd7f4c71f
# 8638       261  /v3/places/4adbbae6f964a520402a21e3
# 8639       561  /v3/places/4ad4c062f964a520e5f720e3
#
#                                                  name         timezone  \
# 0                                        Chorley Park  America/Toronto
# 1                     The Don Valley Brick Works Park  America/Toronto
# 2                               David A. Balfour Park  America/Toronto
# 3                                   Moore Park Ravine  America/Toronto
# 4                                  Rosehill Reservoir  America/Toronto
# ...                                               ...              ...
# 8635                                      Massey Hall  America/Toronto
# 8636                           Chipotle Mexican Grill  America/Toronto
# 8637                                     Burrito Boyz  America/Toronto
# 8638            Cineplex Odeon Yonge & Dundas Cinemas  America/Toronto
# 8639  The Four Seasons Centre for the Performing Arts  America/Toronto
#
#       geocodes.main.latitude  geocodes.main.longitude  ...  \
# 0                  43.687377               -79.370803  ...
# 1                  43.684526               -79.365204  ...
# 2                  43.685607               -79.388253  ...
# 3                  43.693691               -79.379762  ...
# 4                  43.686260               -79.388544  ...
# ...                      ...                      ...  ...
# 8635               43.654096               -79.379167  ...
# 8636               43.656829               -79.380958  ...
# 8637               43.656331               -79.378541  ...
# 8638               43.656582               -79.380498  ...
# 8639               43.650665               -79.385470  ...
#
#       geocodes.drop_off.latitude  geocodes.drop_off.longitude  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
# ...                          ...                          ...
# 8635                         NaN                          NaN
# 8636                         NaN                          NaN
# 8637                         NaN                          NaN
# 8638                         NaN                          NaN
# 8639                         NaN                          NaN
#
#                             station_id related_places.parent.fsq_id  \
# 0     009f180cf35ae1285733d98ccf058313                          NaN
# 1     009f180cf35ae1285733d98ccf058313                          NaN
# 2     009f180cf35ae1285733d98ccf058313                          NaN
# 3     009f180cf35ae1285733d98ccf058313                          NaN
# 4     009f180cf35ae1285733d98ccf058313                          NaN
# ...                                ...                          ...
# 8635  ffeaa2aaedeb18fc11f708bcd8323149                          NaN
# 8636  ffeaa2aaedeb18fc11f708bcd8323149     4adcaacff964a520882e21e3
# 8637  ffeaa2aaedeb18fc11f708bcd8323149                          NaN
# 8638  ffeaa2aaedeb18fc11f708bcd8323149     4adcaacff964a520882e21e3
# 8639  ffeaa2aaedeb18fc11f708bcd8323149                          NaN
#
#                        related_places.parent.categories  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 8635                                                NaN
# 8636  [{'id': 17000, 'name': 'Retail', 'short_name':...
# 8637                                                NaN
# 8638  [{'id': 17000, 'name': 'Retail', 'short_name':...
# 8639                                                NaN
#
#      related_places.parent.name location.address_extended location.po_box  \
# 0                           NaN                       NaN             NaN
# 1                           NaN                       NaN             NaN
# 2                           NaN                       NaN             NaN
# 3                           NaN                       NaN             NaN
# 4                           NaN                       NaN             NaN
# ...                         ...                       ...             ...
# 8635                        NaN              at Shuter St             NaN
# 8636             10 Dundas East                  Unit 114             NaN
# 8637                        NaN                       NaN             NaN
# 8638             10 Dundas East                 Suite 402             NaN
# 8639                        NaN                       NaN             NaN
#
#      geocodes.front_door.latitude geocodes.front_door.longitude
# 0                             NaN                           NaN
# 1                             NaN                           NaN
# 2                             NaN                           NaN
# 3                             NaN                           NaN
# 4                             NaN                           NaN
# ...                           ...                           ...
# 8635                          NaN                           NaN
# 8636                          NaN                           NaN
# 8637                          NaN                           NaN
# 8638                          NaN                           NaN
# 8639                          NaN                           NaN
#
# [8640 rows x 30 columns]

# %% [markdown]
# + dropping unnecessary columns

# %%
columns_to_drop_fs = [
    'chains','closed_bucket','link','timezone', 'location.formatted_address', 'related_places.children', 'geocodes.drop_off.latitude', 'geocodes.drop_off.longitude',
    'geocodes.roof.latitude', 'geocodes.roof.longitude', 'location.country', 'location.cross_street',	'location.locality', 'location.region',
    'related_places.parent.fsq_id',	'related_places.parent.categories',	'related_places.parent.name', 'location.address_extended', 'location.po_box',
    'geocodes.front_door.latitude','geocodes.front_door.longitude'
]

fs_df = fs_df.drop(columns=columns_to_drop_fs)

# %% [markdown]
# + this code was to parse the list of dictionaries in `categories`

# %%
j=0
for row in fs_df['categories']:
    for i in range(len(row)):
        fs_df.at[j,f'category{i}'] = row[i]
    j+=1

# %% [markdown]
# + this extracted the names of the categories from the separated dictionaries

# %%
j=0
for row in fs_df.iterrows():
    fs_df.at[j,'category0_name'] = fs_df.at[j,'category0']['name']
    if type(fs_df.at[j,'category1']) != float: fs_df.at[j,'category1_name'] = fs_df.at[j,'category1']['name']
    if type(fs_df.at[j,'category2']) != float: fs_df.at[j,'category2_name'] = fs_df.at[j,'category2']['name']
    if type(fs_df.at[j,'category3']) != float: fs_df.at[j,'category3_name'] = fs_df.at[j,'category3']['name']
    if type(fs_df.at[j,'category4']) != float: fs_df.at[j,'category4_name'] = fs_df.at[j,'category4']['name']
    if type(fs_df.at[j,'category5']) != float: fs_df.at[j,'category5_name'] = fs_df.at[j,'category5']['name']
    j+=1

# %% [markdown]
# + This code was to extract the category IDs. I ended up not using it for the final dataframe since it wasn't needed, but left it for posterity's sake

# %%
j=0
for row in fs_df.iterrows():
    fs_df.at[j,'category0_id'] = fs_df.at[j,'category0']['id']
    if type(fs_df.at[j,'category1']) != float: fs_df.at[j,'category1_id'] = fs_df.at[j,'category1']['id']
    if type(fs_df.at[j,'category2']) != float: fs_df.at[j,'category2_id'] = fs_df.at[j,'category2']['id']
    if type(fs_df.at[j,'category3']) != float: fs_df.at[j,'category3_id'] = fs_df.at[j,'category3']['id']
    if type(fs_df.at[j,'category4']) != float: fs_df.at[j,'category4_id'] = fs_df.at[j,'category4']['id']
    if type(fs_df.at[j,'category5']) != float: fs_df.at[j,'category5_id'] = fs_df.at[j,'category5']['id']
    j+=1

# %% [markdown]
# + dropping the category columns that are no longer needed

# %%
drop_categories_fs = ['categories', 'category0', 'category1', 'category2', 'category3', 'category4', 'category5']
fs_df = fs_df.drop(columns=drop_categories_fs)

# %%
na_columns_fs={
    'category0_name':'N/A', 'category1_name':'N/A', 'category2_name':'N/A', 'category3_name':'N/A', 'category4_name':'N/A', 'category5_name':'N/A'
    #'category0_id':'N/A', 'category1_id':'N/A', 'category2_id':'N/A', 'category3_id':'N/A', 'category4_id':'N/A', 'category5_id':'N/A'
}
fs_df = fs_df.fillna(value=na_columns_fs)

# %%
to_cat_fs = list(na_columns_fs.keys())

for col in to_cat_fs:
    fs_df[col] = fs_df[col].astype('category')

# %%
rename_columns_fs = {
    'geocodes.main.latitude':'latitude', 'geocodes.main.longitude':'longitude','location.address':'address',
    'location.postcode':'postal_code', 'category0_name':'category0','category1_name':'category1','category2_name':'category2',
    'category3_name':'category3','category4_name':'category4','category5_name':'category5',
}

fs_df = fs_df.rename(columns=rename_columns_fs)

# %%
# creating a pickle to store the dataframe 
fs_df.to_pickle('../data/fs_final_data.pkl')

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
yelp_key = os.getenv('YELP_API_KEY')

# %%
categories_yelp = 'active,arts,education,nightlife,restaurants,shoppingcenters'

# %%
def get_venues_yelp(latitude, longitude, radius, api_key, categories):
    
    url = f"https://api.yelp.com/v3/businesses/search?latitude={latitude}&longitude={longitude}&radius={radius}&categories={categories}&sort_by=best_match&limit=10"

    headers = {
        "accept": "application/json",
        "authorization": f"Bearer {api_key}"
    }
        
    response = requests.get(url, headers=headers)
    response_data = response.json()
    return response_data

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
test_yelp = get_venues_yelp(latitude=43.685924, longitude=-79.376304, radius=1000, api_key=yelp_key, categories=categories_yelp)
pprint.pp(test_yelp)
# Out:
# {'businesses': [{'id': 'GO3d6vQBfByJN93Hco4dOQ',
#                  'alias': 'megumi-mazesoba-toronto',
#                  'name': 'Megumi Mazesoba',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GU87KJbFHYQLvM22NbTQKw/o.jpg',
#                  'is_closed': False,
#                  'url': 'https://www.yelp.com/biz/megumi-mazesoba-toronto?adjust_creative=9GLA4RlrtiBodQwJet7Qrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9GLA4RlrtiBodQwJet7Qrg',
#                  'review_count': 37,
#                  'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#                  'rating': 4.6,
#                  'coordinates': {'latitude': 43.68876, 'longitude': -79.39196},
#                  'transactions': [],
#                  'price': '$$',
#                  'location': {'address1': '46 Saint Clair Avenue E',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Toronto',
#                               'zip_code': 'M4T 1M9',
#                               'country': 'CA',
#                               'state': 'ON',
#                               'display_address': ['46 Saint Clair Avenue E',
#                                                   'Toronto, ON M4T 1M9',
#                                                   'Canada']},
#                  'phone': '+14169293553',
#                  'display_phone': '+1 416-929-3553',
#                  'distance': 1293.173256845786,
#                  'business_hours': [{'open': [{'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '1500',
#                                                'day': 0},
#                                               {'is_overnight': False,
#                                                'start': '1630',
#                                                'end': '2030',
#                                                'day': 0},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '1500',
#                                                'day': 1},
#                                               {'is_overnight': False,
#                                                'start': '1630',
#                                                'end': '2030',
#                                                'day': 1},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '1500',
#                                                'day': 2},
#                                               {'is_overnight': False,
#                                                'start': '1630',
#                                                'end': '2030',
#                                                'day': 2},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '1500',
#                                                'day': 3},
#                                               {'is_overnight': False,
#                                                'start': '1630',
#                                                'end': '2030',
#                                                'day': 3},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '1500',
#                                                'day': 4},
#                                               {'is_overnight': False,
#                                                'start': '1630',
#                                                'end': '2100',
#                                                'day': 4},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '2100',
#                                                'day': 5},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '2000',
#                                                'day': 6}],
#                                      'hours_type': 'REGULAR',
#                                      'is_open_now': True}],
#                  'attributes': {'business_temp_closed': None,
#                                 'menu_url': None,
#                                 'open24_hours': None,
#                                 'waitlist_reservation': None}},
#                 {'id': 'uGLAEGqeJa4jtP1Io0sOrg',
#                  'alias': 'mineral-toronto',
#                  'name': 'Mineral',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3RgKw8gOmubtYrKWoj4m0A/o.jpg',
#                  'is_closed': False,
#                  'url': 'https://www.yelp.com/biz/mineral-toronto?adjust_creative=9GLA4RlrtiBodQwJet7Qrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9GLA4RlrtiBodQwJet7Qrg',
#                  'review_count': 35,
#                  'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#                                 {'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'}],
#                  'rating': 4.5,
#                  'coordinates': {'latitude': 43.67763, 'longitude': -79.38947},
#                  'transactions': [],
#                  'location': {'address1': '1027 Yonge Street',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Toronto',
#                               'zip_code': 'M4W 2K9',
#                               'country': 'CA',
#                               'state': 'ON',
#                               'display_address': ['1027 Yonge Street',
#                                                   'Toronto, ON M4W 2K9',
#                                                   'Canada']},
#                  'phone': '+14169258565',
#                  'display_phone': '+1 416-925-8565',
#                  'distance': 1402.3273522236896,
#                  'business_hours': [{'open': [{'is_overnight': False,
#                                                'start': '1730',
#                                                'end': '2200',
#                                                'day': 1},
#                                               {'is_overnight': False,
#                                                'start': '1730',
#                                                'end': '2200',
#                                                'day': 2},
#                                               {'is_overnight': False,
#                                                'start': '1730',
#                                                'end': '2200',
#                                                'day': 3},
#                                               {'is_overnight': False,
#                                                'start': '1730',
#                                                'end': '0000',
#                                                'day': 4},
#                                               {'is_overnight': False,
#                                                'start': '1730',
#                                                'end': '0000',
#                                                'day': 5}],
#                                      'hours_type': 'REGULAR',
#                                      'is_open_now': True}],
#                  'attributes': {'business_temp_closed': None,
#                                 'menu_url': None,
#                                 'open24_hours': None,
#                                 'waitlist_reservation': None}},
#                 {'id': 'RqOgBMpKYdsEOmBVmFXe3g',
#                  'alias': 'ryus-noodle-bar-toronto-7',
#                  'name': 'RYUS Noodle Bar',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZzsTo2YfIN-owtTqc-OnRg/o.jpg',
#                  'is_closed': False,
#                  'url': 'https://www.yelp.com/biz/ryus-noodle-bar-toronto-7?adjust_creative=9GLA4RlrtiBodQwJet7Qrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9GLA4RlrtiBodQwJet7Qrg',
#                  'review_count': 411,
#                  'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#                  'rating': 4.0,
#                  'coordinates': {'latitude': 43.6771, 'longitude': -79.35905},
#                  'transactions': [],
#                  'price': '$$',
#                  'location': {'address1': '786 Broadview Avenue',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'zip_code': 'M4K 2P7',
#                               'country': 'CA',
#                               'state': 'ON',
#                               'display_address': ['786 Broadview Avenue',
#                                                   'Toronto, ON M4K 2P7',
#                                                   'Canada']},
#                  'phone': '+16473449306',
#                  'display_phone': '+1 647-344-9306',
#                  'distance': 1701.0348687991896,
#                  'business_hours': [{'open': [{'is_overnight': False,
#                                                'start': '1200',
#                                                'end': '2100',
#                                                'day': 1},
#                                               {'is_overnight': False,
#                                                'start': '1200',
#                                                'end': '2100',
#                                                'day': 2},
#                                               {'is_overnight': False,
#                                                'start': '1200',
#                                                'end': '2100',
#                                                'day': 3},
#                                               {'is_overnight': False,
#                                                'start': '1200',
#                                                'end': '2200',
#                                                'day': 4},
#                                               {'is_overnight': False,
#                                                'start': '1200',
#                                                'end': '2200',
#                                                'day': 5},
#                                               {'is_overnight': False,
#                                                'start': '1200',
#                                                'end': '2100',
#                                                'day': 6}],
#                                      'hours_type': 'REGULAR',
#                                      'is_open_now': True}],
#                  'attributes': {'business_temp_closed': None,
#                                 'menu_url': 'https://ryusnoodlebar.com/#Menu',
#                                 'open24_hours': None,
#                                 'waitlist_reservation': None}},
#                 {'id': 'lDpVyjENOz_qbxbRoyBi8w',
#                  'alias': 'black-camel-toronto-2',
#                  'name': 'Black Camel',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/M5V1lmKFl6Ve04JWVX45GQ/o.jpg',
#                  'is_closed': False,
#                  'url': 'https://www.yelp.com/biz/black-camel-toronto-2?adjust_creative=9GLA4RlrtiBodQwJet7Qrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9GLA4RlrtiBodQwJet7Qrg',
#                  'review_count': 399,
#                  'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'}],
#                  'rating': 4.4,
#                  'coordinates': {'latitude': 43.677122232751,
#                                  'longitude': -79.389209714264},
#                  'transactions': [],
#                  'price': '$',
#                  'location': {'address1': '4 Crescent Road',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'zip_code': 'M4W 1S9',
#                               'country': 'CA',
#                               'state': 'ON',
#                               'display_address': ['4 Crescent Road',
#                                                   'Toronto, ON M4W 1S9',
#                                                   'Canada']},
#                  'phone': '+14169297518',
#                  'display_phone': '+1 416-929-7518',
#                  'distance': 1426.5095641961218,
#                  'business_hours': [{'open': [{'is_overnight': False,
#                                                'start': '0700',
#                                                'end': '2000',
#                                                'day': 0},
#                                               {'is_overnight': False,
#                                                'start': '0700',
#                                                'end': '2000',
#                                                'day': 1},
#                                               {'is_overnight': False,
#                                                'start': '0700',
#                                                'end': '2000',
#                                                'day': 2},
#                                               {'is_overnight': False,
#                                                'start': '0700',
#                                                'end': '2000',
#                                                'day': 3},
#                                               {'is_overnight': False,
#                                                'start': '0700',
#                                                'end': '2000',
#                                                'day': 4},
#                                               {'is_overnight': False,
#                                                'start': '1100',
#                                                'end': '2000',
#                                                'day': 5},
#                                               {'is_overnight': False,
#                                                'start': '1100',
#                                                'end': '2000',
#                                                'day': 6}],
#                                      'hours_type': 'REGULAR',
#                                      'is_open_now': False}],
#                  'attributes': {'business_temp_closed': None,
#                                 'menu_url': None,
#                                 'open24_hours': None,
#                                 'waitlist_reservation': None}},
#                 {'id': 'v1hfGBkWhDHIdRIfMJtp5A',
#                  'alias': 'dolce-bakery-toronto',
#                  'name': 'Dolce Bakery',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/91ntLa3tLizPJrZbAjeQpA/o.jpg',
#                  'is_closed': False,
#                  'url': 'https://www.yelp.com/biz/dolce-bakery-toronto?adjust_creative=9GLA4RlrtiBodQwJet7Qrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9GLA4RlrtiBodQwJet7Qrg',
#                  'review_count': 10,
#                  'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#                                 {'alias': 'desserts', 'title': 'Desserts'},
#                                 {'alias': 'pizza', 'title': 'Pizza'}],
#                  'rating': 4.3,
#                  'coordinates': {'latitude': 43.68617, 'longitude': -79.37609},
#                  'transactions': [],
#                  'location': {'address1': '420 Summerhill Avenue',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Toronto',
#                               'zip_code': 'M4W 2E4',
#                               'country': 'CA',
#                               'state': 'ON',
#                               'display_address': ['420 Summerhill Avenue',
#                                                   'Toronto, ON M4W 2E4',
#                                                   'Canada']},
#                  'phone': '+14169222253',
#                  'display_phone': '+1 416-922-2253',
#                  'distance': 25.13882037322987,
#                  'business_hours': [{'open': [{'is_overnight': False,
#                                                'start': '0800',
#                                                'end': '1830',
#                                                'day': 0},
#                                               {'is_overnight': False,
#                                                'start': '0800',
#                                                'end': '1830',
#                                                'day': 1},
#                                               {'is_overnight': False,
#                                                'start': '0800',
#                                                'end': '1830',
#                                                'day': 2},
#                                               {'is_overnight': False,
#                                                'start': '0800',
#                                                'end': '1830',
#                                                'day': 3},
#                                               {'is_overnight': False,
#                                                'start': '0800',
#                                                'end': '1830',
#                                                'day': 4},
#                                               {'is_overnight': False,
#                                                'start': '0800',
#                                                'end': '1830',
#                                                'day': 5},
#                                               {'is_overnight': False,
#                                                'start': '0800',
#                                                'end': '1830',
#                                                'day': 6}],
#                                      'hours_type': 'REGULAR',
#                                      'is_open_now': False}],
#                  'attributes': {'business_temp_closed': None,
#                                 'menu_url': 'https://www.dolcebakery.ca/menus',
#                                 'open24_hours': None,
#                                 'waitlist_reservation': None}},
#                 {'id': 'p1ohbPwI1QfjHQ2zRup5OA',
#                  'alias': 'portici-toronto',
#                  'name': 'Portici',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2c_h3_LKc5YEQIkts6Zldg/o.jpg',
#                  'is_closed': False,
#                  'url': 'https://www.yelp.com/biz/portici-toronto?adjust_creative=9GLA4RlrtiBodQwJet7Qrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9GLA4RlrtiBodQwJet7Qrg',
#                  'review_count': 92,
#                  'categories': [{'alias': 'italian', 'title': 'Italian'},
#                                 {'alias': 'pizza', 'title': 'Pizza'},
#                                 {'alias': 'cafes', 'title': 'Cafes'}],
#                  'rating': 4.0,
#                  'coordinates': {'latitude': 43.67196, 'longitude': -79.39072},
#                  'transactions': [],
#                  'price': '$$',
#                  'location': {'address1': '6 Scollard Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'zip_code': 'M5R 1E9',
#                               'country': 'CA',
#                               'state': 'ON',
#                               'display_address': ['6 Scollard Street',
#                                                   'Toronto, ON M5R 1E9',
#                                                   'Canada']},
#                  'phone': '+16473512235',
#                  'display_phone': '+1 647-351-2235',
#                  'distance': 1776.480493419075,
#                  'business_hours': [{'open': [{'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '2200',
#                                                'day': 0},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '2200',
#                                                'day': 1},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '2200',
#                                                'day': 2},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '2200',
#                                                'day': 3},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '2200',
#                                                'day': 4},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '2200',
#                                                'day': 5},
#                                               {'is_overnight': False,
#                                                'start': '1230',
#                                                'end': '2200',
#                                                'day': 6}],
#                                      'hours_type': 'REGULAR',
#                                      'is_open_now': True}],
#                  'attributes': {'business_temp_closed': None,
#                                 'menu_url': 'http://portici.ca/menu/',
#                                 'open24_hours': None,
#                                 'waitlist_reservation': None}},
#                 {'id': 'XD0LjNuPPwJPsTAHecUh7A',
#                  'alias': 'terroni-toronto-6',
#                  'name': 'Terroni',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dMVuMf74icf31-z-dIJytw/o.jpg',
#                  'is_closed': False,
#                  'url': 'https://www.yelp.com/biz/terroni-toronto-6?adjust_creative=9GLA4RlrtiBodQwJet7Qrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9GLA4RlrtiBodQwJet7Qrg',
#                  'review_count': 356,
#                  'categories': [{'alias': 'italian', 'title': 'Italian'}],
#                  'rating': 3.0,
#                  'coordinates': {'latitude': 43.6800112830789,
#                                  'longitude': -79.3905191478574},
#                  'transactions': [],
#                  'price': '$$$',
#                  'location': {'address1': '1095 Yonge Street',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Toronto',
#                               'zip_code': 'M4W 2L8',
#                               'country': 'CA',
#                               'state': 'ON',
#                               'display_address': ['1095 Yonge Street',
#                                                   'Toronto, ON M4W 2L8',
#                                                   'Canada']},
#                  'phone': '+14169254020',
#                  'display_phone': '+1 416-925-4020',
#                  'distance': 1318.672394552954,
#                  'business_hours': [{'open': [{'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '2200',
#                                                'day': 0},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '2200',
#                                                'day': 1},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '2200',
#                                                'day': 2},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '2300',
#                                                'day': 3},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '2300',
#                                                'day': 4},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '2300',
#                                                'day': 5},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '2200',
#                                                'day': 6}],
#                                      'hours_type': 'REGULAR',
#                                      'is_open_now': True}],
#                  'attributes': {'business_temp_closed': None,
#                                 'menu_url': None,
#                                 'open24_hours': None,
#                                 'waitlist_reservation': None}},
#                 {'id': 'NxpaDfYm8OB14Zw9QDFejA',
#                  'alias': 'tapas-at-embrujo-toronto',
#                  'name': 'Tapas at Embrujo',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/E3Cw9BMuHQGfVJo9Vwp1_g/o.jpg',
#                  'is_closed': False,
#                  'url': 'https://www.yelp.com/biz/tapas-at-embrujo-toronto?adjust_creative=9GLA4RlrtiBodQwJet7Qrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9GLA4RlrtiBodQwJet7Qrg',
#                  'review_count': 115,
#                  'categories': [{'alias': 'tapasmallplates',
#                                  'title': 'Tapas/Small Plates'},
#                                 {'alias': 'spanish', 'title': 'Spanish'}],
#                  'rating': 3.5,
#                  'coordinates': {'latitude': 43.67615,
#                                  'longitude': -79.3582931},
#                  'transactions': [],
#                  'price': '$$$',
#                  'location': {'address1': '97 Danforth Avenue',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'zip_code': 'M4K 1N2',
#                               'country': 'CA',
#                               'state': 'ON',
#                               'display_address': ['97 Danforth Avenue',
#                                                   'Toronto, ON M4K 1N2',
#                                                   'Canada']},
#                  'phone': '+16477057880',
#                  'display_phone': '+1 647-705-7880',
#                  'distance': 1810.7768715553957,
#                  'business_hours': [{'open': [{'is_overnight': False,
#                                                'start': '1700',
#                                                'end': '2300',
#                                                'day': 1},
#                                               {'is_overnight': False,
#                                                'start': '1700',
#                                                'end': '2300',
#                                                'day': 2},
#                                               {'is_overnight': False,
#                                                'start': '1700',
#                                                'end': '2300',
#                                                'day': 3},
#                                               {'is_overnight': False,
#                                                'start': '1700',
#                                                'end': '2300',
#                                                'day': 4},
#                                               {'is_overnight': False,
#                                                'start': '1700',
#                                                'end': '2300',
#                                                'day': 5},
#                                               {'is_overnight': False,
#                                                'start': '1600',
#                                                'end': '2100',
#                                                'day': 6}],
#                                      'hours_type': 'REGULAR',
#                                      'is_open_now': True}],
#                  'attributes': {'business_temp_closed': None,
#                                 'menu_url': 'http://www.tapasatembrujo.com/menus/',
#                                 'open24_hours': None,
#                                 'waitlist_reservation': None}},
#                 {'id': '3cAy1gxlprn1ue0q3L_ziw',
#                  'alias': 'lee-chen-bistro-toronto',
#                  'name': 'Lee Chen Bistro',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NrVLERwldPbZcItrnA5EFw/o.jpg',
#                  'is_closed': False,
#                  'url': 'https://www.yelp.com/biz/lee-chen-bistro-toronto?adjust_creative=9GLA4RlrtiBodQwJet7Qrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9GLA4RlrtiBodQwJet7Qrg',
#                  'review_count': 183,
#                  'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'},
#                                 {'alias': 'asianfusion',
#                                  'title': 'Asian Fusion'},
#                                 {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#                  'rating': 3.6,
#                  'coordinates': {'latitude': 43.672372,
#                                  'longitude': -79.387436},
#                  'transactions': [],
#                  'price': '$$',
#                  'location': {'address1': '813 Yonge Street',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Toronto',
#                               'zip_code': 'M4W 2G9',
#                               'country': 'CA',
#                               'state': 'ON',
#                               'display_address': ['813 Yonge Street',
#                                                   'Toronto, ON M4W 2G9',
#                                                   'Canada']},
#                  'phone': '+14169018869',
#                  'display_phone': '+1 416-901-8869',
#                  'distance': 1752.7672862608895,
#                  'business_hours': [{'open': [{'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '2200',
#                                                'day': 0},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '2200',
#                                                'day': 1},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '2200',
#                                                'day': 2},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '2200',
#                                                'day': 3},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '2200',
#                                                'day': 4},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '2200',
#                                                'day': 5},
#                                               {'is_overnight': False,
#                                                'start': '1130',
#                                                'end': '2200',
#                                                'day': 6}],
#                                      'hours_type': 'REGULAR',
#                                      'is_open_now': True}],
#                  'attributes': {'business_temp_closed': None,
#                                 'menu_url': None,
#                                 'open24_hours': None,
#                                 'waitlist_reservation': None}},
#                 {'id': 'Cra7jGcAh_McPTHpm9YlTQ',
#                  'alias': 'umami-poke-toronto',
#                  'name': 'Umami Poke',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yM_0I5POPfPpXlfS1TNBrA/o.jpg',
#                  'is_closed': False,
#                  'url': 'https://www.yelp.com/biz/umami-poke-toronto?adjust_creative=9GLA4RlrtiBodQwJet7Qrg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=9GLA4RlrtiBodQwJet7Qrg',
#                  'review_count': 57,
#                  'categories': [{'alias': 'hawaiian', 'title': 'Hawaiian'},
#                                 {'alias': 'seafood', 'title': 'Seafood'},
#                                 {'alias': 'poke', 'title': 'Poke'}],
#                  'rating': 4.6,
#                  'coordinates': {'latitude': 43.68318, 'longitude': -79.39229},
#                  'transactions': [],
#                  'price': '$$',
#                  'location': {'address1': '1252 Yonge Street',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Toronto',
#                               'zip_code': 'M4T 1W5',
#                               'country': 'CA',
#                               'state': 'ON',
#                               'display_address': ['1252 Yonge Street',
#                                                   'Toronto, ON M4T 1W5',
#                                                   'Canada']},
#                  'phone': '+16473516998',
#                  'display_phone': '+1 647-351-6998',
#                  'distance': 1321.807421208853,
#                  'business_hours': [{'open': [{'is_overnight': False,
#                                                'start': '1100',
#                                                'end': '2000',
#                                                'day': 0},
#                                               {'is_overnight': False,
#                                                'start': '1100',
#                                                'end': '2000',
#                                                'day': 1},
#                                               {'is_overnight': False,
#                                                'start': '1100',
#                                                'end': '2000',
#                                                'day': 2},
#                                               {'is_overnight': False,
#                                                'start': '1100',
#                                                'end': '2000',
#                                                'day': 3},
#                                               {'is_overnight': False,
#                                                'start': '1100',
#                                                'end': '2000',
#                                                'day': 4},
#                                               {'is_overnight': False,
#                                                'start': '1100',
#                                                'end': '1900',
#                                                'day': 5},
#                                               {'is_overnight': False,
#                                                'start': '1200',
#                                                'end': '1800',
#                                                'day': 6}],
#                                      'hours_type': 'REGULAR',
#                                      'is_open_now': False}],
#                  'attributes': {'business_temp_closed': None,
#                                 'menu_url': None,
#                                 'open24_hours': None,
#                                 'waitlist_reservation': None}}],
#  'total': 333,
#  'region': {'center': {'longitude': -79.376304, 'latitude': 43.685924}}}

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
yelp_df = pd.DataFrame()
for index, row in bike_stations.iterrows():
    yelp_venues = get_venues_yelp(latitude=row['latitude'], longitude=row['longitude'], radius=1000, api_key=yelp_key, categories=categories_yelp)
    temp_df = pd.json_normalize(yelp_venues, record_path=['businesses'])
    temp_df['station_id'] = row['id']
    yelp_df = pd.concat([yelp_df, temp_df], ignore_index=True)

# %%
yelp_df = pd.read_pickle('../data/yelp.pkl')

# %%
print(yelp_df.shape)
print(yelp_df.columns)
# Out:
# (8640, 30)
# Index(['id', 'alias', 'name', 'image_url', 'is_closed', 'url', 'review_count',
#        'categories', 'rating', 'transactions', 'price', 'phone',
#        'display_phone', 'distance', 'business_hours', 'coordinates.latitude',
#        'coordinates.longitude', 'location.address1', 'location.address2',
#        'location.address3', 'location.city', 'location.zip_code',
#        'location.country', 'location.state', 'location.display_address',
#        'attributes.business_temp_closed', 'attributes.menu_url',
#        'attributes.open24_hours', 'attributes.waitlist_reservation',
#        'station_id'],
#       dtype='object')

# %%
yelp_df
# Out:
#                           id                                alias  \
# 0     GO3d6vQBfByJN93Hco4dOQ              megumi-mazesoba-toronto
# 1     uGLAEGqeJa4jtP1Io0sOrg                      mineral-toronto
# 2     lDpVyjENOz_qbxbRoyBi8w                black-camel-toronto-2
# 3     RqOgBMpKYdsEOmBVmFXe3g            ryus-noodle-bar-toronto-7
# 4     v1hfGBkWhDHIdRIfMJtp5A                 dolce-bakery-toronto
# ...                      ...                                  ...
# 8635  6eRSdODyj9GS0w6zlhrWkg            adega-restaurante-toronto
# 8636  7ODXq--HE7QpzvWwgk5rMA       barberians-steak-house-toronto
# 8637  wpQsmMvdhefqIlxvRt_Jbg             dondon-izakaya-toronto-3
# 8638  mZRKH9ngRY92bI_irrHq6w             richmond-station-toronto
# 8639  r_BrIgzYcwo1NAuG9dLbpg  pai-northern-thai-kitchen-toronto-5
#
#                            name  \
# 0               Megumi Mazesoba
# 1                       Mineral
# 2                   Black Camel
# 3               RYUS Noodle Bar
# 4                  Dolce Bakery
# ...                         ...
# 8635          Adega Restaurante
# 8636    Barberian's Steak House
# 8637             DonDon Izakaya
# 8638           Richmond Station
# 8639  Pai Northern Thai Kitchen
#
#                                               image_url  is_closed  \
# 0     https://s3-media4.fl.yelpcdn.com/bphoto/GU87KJ...      False
# 1     https://s3-media3.fl.yelpcdn.com/bphoto/3RgKw8...      False
# 2     https://s3-media2.fl.yelpcdn.com/bphoto/M5V1lm...      False
# 3     https://s3-media2.fl.yelpcdn.com/bphoto/ZzsTo2...      False
# 4     https://s3-media1.fl.yelpcdn.com/bphoto/91ntLa...      False
# ...                                                 ...        ...
# 8635  https://s3-media4.fl.yelpcdn.com/bphoto/U-L0Qj...      False
# 8636  https://s3-media1.fl.yelpcdn.com/bphoto/kWOWiD...      False
# 8637  https://s3-media2.fl.yelpcdn.com/bphoto/KrH_2X...      False
# 8638  https://s3-media3.fl.yelpcdn.com/bphoto/agCQCt...      False
# 8639  https://s3-media4.fl.yelpcdn.com/bphoto/uAnTcm...      False
#
#                                                     url  review_count  \
# 0     https://www.yelp.com/biz/megumi-mazesoba-toron...            37
# 1     https://www.yelp.com/biz/mineral-toronto?adjus...            35
# 2     https://www.yelp.com/biz/black-camel-toronto-2...           399
# 3     https://www.yelp.com/biz/ryus-noodle-bar-toron...           411
# 4     https://www.yelp.com/biz/dolce-bakery-toronto?...            10
# ...                                                 ...           ...
# 8635  https://www.yelp.com/biz/adega-restaurante-tor...           170
# 8636  https://www.yelp.com/biz/barberians-steak-hous...           362
# 8637  https://www.yelp.com/biz/dondon-izakaya-toront...           361
# 8638  https://www.yelp.com/biz/richmond-station-toro...           962
# 8639  https://www.yelp.com/biz/pai-northern-thai-kit...          3787
#
#                                              categories  rating transactions  \
# 0          [{'alias': 'japanese', 'title': 'Japanese'}]     4.6           []
# 1     [{'alias': 'noodles', 'title': 'Noodles'}, {'a...     4.5           []
# 2      [{'alias': 'sandwiches', 'title': 'Sandwiches'}]     4.4           []
# 3                [{'alias': 'ramen', 'title': 'Ramen'}]     4.0           []
# 4     [{'alias': 'bakeries', 'title': 'Bakeries'}, {...     4.3           []
# ...                                                 ...     ...          ...
# 8635  [{'alias': 'portuguese', 'title': 'Portuguese'...     4.1           []
# 8636       [{'alias': 'steak', 'title': 'Steakhouses'}]     3.9           []
# 8637  [{'alias': 'japanese', 'title': 'Japanese'}, {...     3.1           []
# 8638  [{'alias': 'newcanadian', 'title': 'Canadian (...     4.4           []
# 8639               [{'alias': 'thai', 'title': 'Thai'}]     4.4           []
#
#       ... location.city location.zip_code location.country  location.state  \
# 0     ...       Toronto           M4T 1M9               CA              ON
# 1     ...       Toronto           M4W 2K9               CA              ON
# 2     ...       Toronto           M4W 1S9               CA              ON
# 3     ...       Toronto           M4K 2P7               CA              ON
# 4     ...       Toronto           M4W 2E4               CA              ON
# ...   ...           ...               ...              ...             ...
# 8635  ...       Toronto           M5G 1H1               CA              ON
# 8636  ...       Toronto           M5G 1H1               CA              ON
# 8637  ...       Toronto           M5G 1C3               CA              ON
# 8638  ...       Toronto           M5H 3W4               CA              ON
# 8639  ...       Toronto           M5H 3G8               CA              ON
#
#                                location.display_address  \
# 0     [46 Saint Clair Avenue E, Toronto, ON M4T 1M9,...
# 1      [1027 Yonge Street, Toronto, ON M4W 2K9, Canada]
# 2        [4 Crescent Road, Toronto, ON M4W 1S9, Canada]
# 3     [786 Broadview Avenue, Toronto, ON M4K 2P7, Ca...
# 4     [420 Summerhill Avenue, Toronto, ON M4W 2E4, C...
# ...                                                 ...
# 8635           [33 Elm St, Toronto, ON M5G 1H1, Canada]
# 8636        [7 Elm Street, Toronto, ON M5G 1H1, Canada]
# 8637  [130 Dundas Street West, Toronto, ON M5G 1C3, ...
# 8638  [1 Richmond Street W, Toronto, ON M5H 3W4, Can...
# 8639    [18 Duncan Street, Toronto, ON M5H 3G8, Canada]
#
#       attributes.business_temp_closed                attributes.menu_url  \
# 0                                 NaN                               None
# 1                                 NaN                               None
# 2                                 NaN                               None
# 3                                 NaN    https://ryusnoodlebar.com/#Menu
# 4                                 NaN   https://www.dolcebakery.ca/menus
# ...                               ...                                ...
# 8635                              NaN                               None
# 8636                              NaN        http://barberians.com/menu/
# 8637                              NaN  http://www.dondonizakaya.com/menu
# 8638                              NaN   https://richmondstation.ca/menu/
# 8639                              NaN                               None
#
#      attributes.open24_hours attributes.waitlist_reservation  \
# 0                       None                            None
# 1                       None                            None
# 2                       None                            None
# 3                       None                            None
# 4                       None                            None
# ...                      ...                             ...
# 8635                    None                            None
# 8636                    None                            None
# 8637                    None                            None
# 8638                    None                            None
# 8639                    None                            None
#
#                             station_id
# 0     009f180cf35ae1285733d98ccf058313
# 1     009f180cf35ae1285733d98ccf058313
# 2     009f180cf35ae1285733d98ccf058313
# 3     009f180cf35ae1285733d98ccf058313
# 4     009f180cf35ae1285733d98ccf058313
# ...                                ...
# 8635  ffeaa2aaedeb18fc11f708bcd8323149
# 8636  ffeaa2aaedeb18fc11f708bcd8323149
# 8637  ffeaa2aaedeb18fc11f708bcd8323149
# 8638  ffeaa2aaedeb18fc11f708bcd8323149
# 8639  ffeaa2aaedeb18fc11f708bcd8323149
#
# [8640 rows x 30 columns]

# %%
columns_to_drop_yelp = [
    'alias', 'image_url', 'is_closed', 'url', 'transactions', 'phone', 'display_phone','business_hours',
    'location.address2', 'location.address3', 'location.city', 'location.country', 'location.state',
    'location.display_address','attributes.business_temp_closed', 'attributes.menu_url', 'attributes.open24_hours', 
    'attributes.waitlist_reservation'
]

yelp_df = yelp_df.drop(columns=columns_to_drop_yelp)

# %% [markdown]
# + just like for FourSquare, this was to extract the category names

# %%
j=0
for row in yelp_df['categories']:
    for i in range(len(row)):
        yelp_df.at[j,f'category{i}'] = row[i]
    j+=1

# %%
j=0
for row in yelp_df.iterrows():
    yelp_df.at[j,'category0_name'] = yelp_df.at[j,'category0']['title']
    if type(yelp_df.at[j,'category1']) != float: yelp_df.at[j,'category1_name'] = yelp_df.at[j,'category1']['title']
    if type(yelp_df.at[j,'category2']) != float: yelp_df.at[j,'category2_name'] = yelp_df.at[j,'category2']['title']
    if type(yelp_df.at[j,'category3']) != float: yelp_df.at[j,'category3_name'] = yelp_df.at[j,'category3']['title']
    j+=1

# %%
drop_categories_yelp = ['categories', 'category0', 'category1', 'category2', 'category3']
yelp_df = yelp_df.drop(columns=drop_categories_yelp)

# %%
na_columns_yelp={
    'category0_name':'N/A', 'category1_name':'N/A', 'category2_name':'N/A', 'category3_name':'N/A', 'price':'N/A'
}

yelp_df = yelp_df.fillna(value=na_columns_yelp)

# %%
to_cat_yelp = list(na_columns_yelp.keys())

for col in to_cat_yelp:
    yelp_df[col] = yelp_df[col].astype('category')

# %%
rename_columns_yelp = {
    'id':'yelp_id', 'coordinates.latitude':'latitude', 'coordinates.longitude':'longitude', 'location.address1':'address',
    'location.zip_code':'postal_code','category0_name':'category0', 'category1_name':'category1', 'category2_name':'category2',
    'category3_name':'category3'
}

yelp_df = yelp_df.rename(columns=rename_columns_yelp)

# %%
yelp_df.to_pickle('../data/yelp_final_data.pkl')

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# For the purposes of this project, the Yelp API provided more complete data. When calling the API for a list of businesses, they both provide basic business details. FourSquare extends on this by providing an exhaustive list of geolocation information, whereas Yelp provides information on ratings which is more useful to us.
#
# If we were to call both APIs for business details then they both provide a wealth of information, though FourSquare includes social media links and quite a few more attributes. This wasn't done for this project to limit the amount of calls used.
#
# A strange quirk of the Yelp API is that it doesn't strictly adhere to the radius provided and instead uses it as a suggestion, whereas Foursquare respected the radius value.
#
# The categories between the APIs aren't directly comparable making it difficult to draw any conclusions based off of the amount of unique categories, though I still included the totals.

# %%
print('FourSquare Data')
fs_df.head()
# Out:
# FourSquare Data
#                      fsq_id  distance                             name  \
# 0  4ae48f90f964a520ad9b21e3       470                     Chorley Park
# 1  4dfe2ca5185009bba4df0608       905  The Don Valley Brick Works Park
# 2  4bf031dcf831c928eab401f2       960            David A. Balfour Park
# 3  4dfe2d6d185009bba4df0672       906                Moore Park Ravine
# 4  4bc0d290920eb713dda1192c       984               Rosehill Reservoir
#
#     latitude  longitude                address postal_code  \
# 0  43.687377 -79.370803         250 Douglas Dr     M4W 2C1
# 1  43.684526 -79.365204        550 Bayview Ave     M4W 3X8
# 2  43.685607 -79.388253  200 Mount Pleasant Rd     M4T 2C4
# 3  43.693691 -79.379762          205 Moore Ave     M4T 2K7
# 4  43.686260 -79.388544        75 Rosehill Ave         NaN
#
#                          station_id category0              category1  \
# 0  009f180cf35ae1285733d98ccf058313      Park                    N/A
# 1  009f180cf35ae1285733d98ccf058313      Park                    N/A
# 2  009f180cf35ae1285733d98ccf058313      Park  Sports and Recreation
# 3  009f180cf35ae1285733d98ccf058313      Park  Sports and Recreation
# 4  009f180cf35ae1285733d98ccf058313      Park                    N/A
#
#   category2 category3 category4 category5
# 0       N/A       N/A       N/A       N/A
# 1       N/A       N/A       N/A       N/A
# 2       N/A       N/A       N/A       N/A
# 3       N/A       N/A       N/A       N/A
# 4       N/A       N/A       N/A       N/A

# %%
print('Yelp Data')
yelp_df.head()
# Out:
# Yelp Data
#                   yelp_id             name  review_count  rating price  \
# 0  GO3d6vQBfByJN93Hco4dOQ  Megumi Mazesoba            37     4.6    $$
# 1  uGLAEGqeJa4jtP1Io0sOrg          Mineral            35     4.5   N/A
# 2  lDpVyjENOz_qbxbRoyBi8w      Black Camel           399     4.4     $
# 3  RqOgBMpKYdsEOmBVmFXe3g  RYUS Noodle Bar           411     4.0    $$
# 4  v1hfGBkWhDHIdRIfMJtp5A     Dolce Bakery            10     4.3   N/A
#
#       distance   latitude  longitude                  address postal_code  \
# 0  1293.173257  43.688760  -79.39196  46 Saint Clair Avenue E     M4T 1M9
# 1  1402.327352  43.677630  -79.38947        1027 Yonge Street     M4W 2K9
# 2  1426.509564  43.677122  -79.38921          4 Crescent Road     M4W 1S9
# 3  1701.034869  43.677100  -79.35905     786 Broadview Avenue     M4K 2P7
# 4    25.138820  43.686170  -79.37609    420 Summerhill Avenue     M4W 2E4
#
#                          station_id   category0 category1     category2  \
# 0  009f180cf35ae1285733d98ccf058313    Japanese       N/A           N/A
# 1  009f180cf35ae1285733d98ccf058313     Noodles   Seafood  Asian Fusion
# 2  009f180cf35ae1285733d98ccf058313  Sandwiches       N/A           N/A
# 3  009f180cf35ae1285733d98ccf058313       Ramen       N/A           N/A
# 4  009f180cf35ae1285733d98ccf058313    Bakeries  Desserts         Pizza
#
#   category3
# 0       N/A
# 1       N/A
# 2       N/A
# 3       N/A
# 4       N/A

# %%
all_categories_fs = []

for column in list(fs_df.columns):
    if column.startswith('category') == True: all_categories_fs.extend(list(fs_df[f'{column}'].value_counts().index))

unique_categories_fs = set(all_categories_fs)
print('Unique FourSquare Categories:', len(unique_categories_fs))

all_categories_yelp = []

for column in list(yelp_df.columns):
    if column.startswith('category') == True: all_categories_yelp.extend(list(yelp_df[f'{column}'].value_counts().index))

unique_categories_yelp = set(all_categories_yelp)
print('Unique Yelp Categories:', len(unique_categories_yelp))
# Out:
# Unique FourSquare Categories: 311
# Unique Yelp Categories: 237

# %% [markdown]
# + This isn't directly comparable because how each defines their categories can be different, and because Yelp uses radius as a suggestion. I still wanted to see how manyt resulting categories I got for each

# %% [markdown]
# Get the top 10 restaurants according to their rating

# %%
yelp_df.sort_values(by='rating', ascending=False).head(10)
# Out:
#                      yelp_id                      name  review_count  rating  \
# 407   a3q0ulHNNP8OnOKc0mBWRA     Jong Park Tae Kwon Do             1     5.0
# 5068  igaTtgKFrp-6X9-TBHxE_g                  Pinochio             4     5.0
# 4465  1kGDxmL3PxsJZgbdJWDChQ  Looking Glass Adventures            10     5.0
# 4419  Uf00W5Yrqn7Pq6W-IfGXQw       Bereket Kebab House             3     5.0
# 5658  zXxpMUZdS8lhs6F4PMYHlA          Grapefully Yours             2     5.0
# 5691  9dV86LKzD6WNPTf3FDiT_A   Lume Kitchen and Lounge             8     5.0
# 2109  trg8oGeN5dErZw9mfyzV8g                 Ocak Basi             4     5.0
# 3598  gMS5zYPhK3DKWhzjKSu_sg  Bhuri Bhoj - Happy Tummy             1     5.0
# 7117  MhRpSowt0btjV4mUplTQ6g                    Greelz             1     5.0
# 8488  NwsTOsBOUWn-9le4rY7Q_w               Omni Noodle             2     5.0
#
#      price     distance   latitude  longitude                 address  \
# 407    N/A    32.167055  43.745538 -79.209955      3730 Kingston Road
# 5068   N/A  1256.737836  43.733735 -79.532453   45 Abraham Welsh Road
# 4465   N/A  1822.290348  43.690473 -79.292976    2944 Danforth Avenue
# 4419   N/A   251.764590  43.768871 -79.185653  245 Morningside Ave D2
# 5658     $   170.906339  43.737204 -79.218490        3467 Kingston Rd
# 5691   N/A    76.259847  43.624228 -79.484404       72 Park Lawn Road
# 2109   N/A   756.555869  43.766140 -79.467730    4544 Dufferin Street
# 3598   N/A    90.101609  43.749110 -79.542740          3390 Weston Rd
# 7117   N/A   669.529615  43.690240 -79.498990        1354 Weston Road
# 8488   N/A   136.037651  43.770239 -79.499332       115 Haynes Avenue
#
#      postal_code                        station_id             category0  \
# 407      M1J 3H3  0b46fa9ccc3ac1fa00d279abd7e73df2             Taekwondo
# 5068     M9M 0C5  97416e3d0063fa4952e8e667f7a6de08              Desserts
# 4465     M4C 1M5  84e8e3827807916c9c3ac9b60404346d          Escape Games
# 4419     M1E 3E6  843602f3de2dc3c06cfacd5bf0a1a0fe               Turkish
# 5658     M1M 1R4  a96febb839b2b9bb6b6faee220f3f8c1  Beer, Wine & Spirits
# 5691     M8Y 3H8  ab463b4b4fbf00bbfbe972989481ed7d               Lounges
# 2109     M3H 5X2  3b8388fb5baa35cdc62ea9a8f7bb5fd7               Turkish
# 3598     M9M 2X3  6bd88200486000a93cc1ca5b78bc5ba9                Indian
# 7117     M6M 4R8  d310230182f10034968c97f0c799ee0b               Burgers
# 8488     M3J 0L8  fbc181887030746137034a35fb5f7cfd               Noodles
#
#                category1                  category2 category3
# 407                  N/A                        N/A       N/A
# 5068               Cafes  Ice Cream & Frozen Yogurt       N/A
# 4465                 N/A                        N/A       N/A
# 4419                 N/A                        N/A       N/A
# 5658            Wineries                        N/A       N/A
# 5691  Breakfast & Brunch              Cocktail Bars       N/A
# 2109               Kebab                        N/A       N/A
# 3598            Caterers                        N/A       N/A
# 7117            Barbeque                  Fast Food       N/A
# 8488                 N/A                        N/A       N/A
